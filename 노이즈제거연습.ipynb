# %%
import re

def preprocess_text(text):
    # HTML 태그 제거
    text = re.sub(r'<[^>]+>', '', text)
    # 특수 문자 제거
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # 대소문자 통일
    text = text.lower()
    return text

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in stemmed_words]
    return ' '.join(lemmatized_words)

# %%
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# %%
from transformers import pipeline

# 사전 학습된 BERT 모델을 사용한 텍스트 복구 예제
fill_mask = pipeline("fill-mask", model="bert-base-uncased")

def recover_text(text):
    # 예시: [MASK] 위치에 적절한 단어를 예측
    recovered_text = fill_mask(text)
    return recovered_text

# %%
def clean_and_recover_wikipedia_text(text):
    # 전처리
    text = preprocess_text(text)
    # 불용어 제거
    text = remove_stopwords(text)
    # 어간 추출 및 표제어 추출
    text = stem_and_lemmatize(text)
    # 길이 필터링
    text = filter_by_length(text)
    if text is None:
        return None
    # 텍스트 복구
    recovered_text = recover_text(text)
    return recovered_text

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from transformers import pipeline
from spellchecker import SpellChecker

# NLTK 리소스 다운로드
nltk.download('stopwords')
nltk.download('punkt')

# 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.lower()
    return text

# 불용어 제거 함수
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 어간 추출 및 표제어 추출 함수
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in stemmed_words]
    return ' '.join(lemmatized_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 철자 검사 및 수정 함수
spell = SpellChecker()

def correct_spelling(text):
    words = word_tokenize(text)
    corrected_words = [spell.correction(word) for word in words]
    return ' '.join(corrected_words)

# 텍스트 복구 함수 (BERT 모델 사용)
fill_mask = pipeline("fill-mask", model="bert-base-uncased")

def recover_text(text):
    masked_text = text.replace('[MASK]', '<mask>')
    recovered = fill_mask(masked_text)
    return recovered[0]['sequence'] if recovered else text

# 파일에서 데이터 읽기
file_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia.txt/processed_wikipedia.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 데이터 정화 및 복구
cleaned_lines = []
for line in lines:
    cleaned_line = preprocess_text(line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    if cleaned_line:
        cleaned_line = recover_text(cleaned_line)
        cleaned_lines.append(cleaned_line)

# 결과를 파일에 저장
output_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia_cleaned.txt'
with open(output_path, 'w', encoding='utf-8') as file:
    for cleaned_line in cleaned_lines:
        file.write(cleaned_line + '\n')

# 상위 10개의 데이터 출력
print("Top 10 cleaned data samples:")
for i in range(min(10, len(cleaned_lines))):
    print(f"{i+1}: {cleaned_lines[i]}")

print(f"\nData cleaned and saved to {output_path}")
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from transformers import pipeline
from spellchecker import SpellChecker

# NLTK 리소스 다운로드
nltk.download('stopwords')
nltk.download('punkt')

# 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.lower()
    return text

# 불용어 제거 함수
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 어간 추출 및 표제어 추출 함수
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in stemmed_words]
    return ' '.join(stemmed_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 철자 검사 및 수정 함수
spell = SpellChecker()

def correct_spelling(text):
    words = word_tokenize(text)
    corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
    return ' '.join(corrected_words)

# 텍스트 복구 함수 (BERT 모델 사용)
fill_mask = pipeline("fill-mask", model="bert-base-uncased")

def recover_text(text):
    masked_text = text.replace('[MASK]', '<mask>')
    recovered = fill_mask(masked_text)
    return recovered[0]['sequence'] if recovered else text

# 파일에서 데이터 읽기
file_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia.txt/processed_wikipedia.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 데이터 정화 및 복구
cleaned_lines = []
for line in lines:
    cleaned_line = preprocess_text(line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    if cleaned_line:  # None 체크
        cleaned_line = recover_text(cleaned_line)
        if cleaned_line:  # None 체크
            cleaned_lines.append(cleaned_line)

# 결과를 파일에 저장
output_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia_cleaned.txt'
with open(output_path, 'w', encoding='utf-8') as file:
    for cleaned_line in cleaned_lines:
        file.write(cleaned_line + '\n')

# 상위 10개의 데이터 출력
print("Top 10 cleaned data samples:")
for i in range(min(10, len(cleaned_lines))):
    print(f"{i+1}: {cleaned_lines[i]}")

print(f"\nData cleaned and saved to {output_path}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eternal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eternal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 68
#      66 cleaned_line = preprocess_text(line)
#      67 cleaned_line = remove_stopwords(cleaned_line)
# ---> 68 cleaned_line = correct_spelling(cleaned_line)
#      69 cleaned_line = stem_and_lemmatize(cleaned_line)
#      70 cleaned_line = filter_by_length(cleaned_line)
#
# Cell In[7], line 48, in correct_spelling(text)
#      46 words = word_tokenize(text)
#      47 corrected_words = [spell.correction(word) for word in words]
# ---> 48 return ' '.join(corrected_words)
#
# TypeError: sequence item 1: expected str instance, NoneType found

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from transformers import pipeline
from spellchecker import SpellChecker
from tqdm import tqdm

# NLTK 리소스 다운로드
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.lower()
    return text

# 불용어 제거 함수
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 어간 추출 및 표제어 추출 함수
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 철자 검사 및 수정 함수
spell = SpellChecker()

def correct_spelling(text):
    words = word_tokenize(text)
    corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
    return ' '.join(corrected_words)

# 텍스트 복구 함수 (BERT 모델 사용)
fill_mask = pipeline("fill-mask", model="bert-base-uncased")

def recover_text(text):
    if '[MASK]' in text:
        masked_text = text.replace('[MASK]', '<mask>')
        recovered = fill_mask(masked_text)
        return recovered[0]['sequence'] if recovered else text
    else:
        return text  # [MASK] 토큰이 없으면 원래 텍스트 반환

# 파일에서 데이터 읽기
file_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia.txt/processed_wikipedia.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    lines = file.readlines()

# 데이터 정화 및 복구
cleaned_lines = []
for line in tqdm(lines, desc="Processing lines"):
    cleaned_line = preprocess_text(line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    if cleaned_line:  # None 체크
        cleaned_line = recover_text(cleaned_line)
        if cleaned_line:  # None 체크
            cleaned_lines.append(cleaned_line)

# 결과를 파일에 저장
output_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia_cleaned.txt'
with open(output_path, 'w', encoding='utf-8') as file:
    for cleaned_line in cleaned_lines:
        file.write(cleaned_line + '\n')

# 상위 10개의 데이터 출력
print("Top 10 cleaned data samples:")
for i in range(min(10, len(cleaned_lines))):
    print(f"{i+1}: {cleaned_lines[i]}")

print(f"\nData cleaned and saved to {output_path}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eternal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eternal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/eternal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Processing lines:   0%|       | 24322/105502474 [7:21:42<27322:09:28,  1.07it/s]

# %%
import re

# 파일에서 데이터 읽기
file_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia.txt/processed_wikipedia.txt'
with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# 단어 수 세기
def count_words(text):
    # 특수 문자 제거
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # 단어 단위로 분할
    words = text.split()
    # 단어 수 반환
    return len(words)

word_count = count_words(text)
print(f"Total number of words in the file: {word_count}")

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from spellchecker import SpellChecker
from tqdm import tqdm

# NLTK 리소스 다운로드
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.lower()
    return text

# 불용어 제거 함수
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 어간 추출 및 표제어 추출 함수
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 철자 검사 및 수정 함수
spell = SpellChecker()

def correct_spelling(text):
    words = word_tokenize(text)
    corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
    return ' '.join(corrected_words)

# 단어 수 세기 함수
def count_words(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    words = text.split()
    return len(words)

# 데이터 정화 및 복구 함수
def clean_line(line):
    cleaned_line = preprocess_text(line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    return cleaned_line

# 파일에서 데이터 읽기
file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'

# 결과를 저장할 파일 열기
output_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_cleaned.txt'
with open(output_path, 'w', encoding='utf-8') as output_file:

    # 청크 단위로 데이터를 읽고 처리
    chunk_size = 1000
    total_lines = 0
    processed_word_count = 0

    with open(file_path, 'r', encoding='utf-8') as file:
        while True:
            lines = file.readlines(chunk_size)
            if not lines:
                break

            cleaned_lines = []
            for line in tqdm(lines, desc="Processing lines"):
                cleaned_line = clean_line(line)
                if cleaned_line:  # None 체크
                    cleaned_lines.append(cleaned_line)

            # 처리된 데이터의 단어 수 계산
            processed_text = ' '.join(cleaned_lines)
            processed_word_count += count_words(processed_text)

            # 결과를 파일에 저장
            for cleaned_line in cleaned_lines:
                output_file.write(cleaned_line + '\n')

            total_lines += len(lines)

print(f"Total lines processed: {total_lines}")
print(f"Processed word count: {processed_word_count}")

# 상위 10개의 데이터 출력
with open(output_path, 'r', encoding='utf-8') as file:
    print("Top 10 cleaned data samples:")
    for i in range(10):
        print(f"{i+1}: {file.readline().strip()}")

print(f"\nData cleaned and saved to {output_path}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eternal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eternal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/eternal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Processing lines: 100%|███████████████████████████| 8/8 [00:07<00:00,  1.12it/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:09<00:00,  1.22s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:07<00:00,  1.00s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:08<00:00,  1.05s/it]
# Processing lines: 100%|███████████████████████████| 9/9 [00:07<00:00,  1.23it/s]
# Processing lines: 100%|█████████████████████████| 10/10 [00:07<00:00,  1.35it/s]
# Processing lines: 100%|███████████████████████████| 9/9 [00:07<00:00,  1.14it/s]
# Processing lines: 100%|███████████████████████████| 7/7 [00:07<00:00,  1.10s/it]
# Processing lines: 100%|█████████████████████████| 11/11 [00:10<00:00,  1.03it/s]
# Processing lines: 100%|███████████████████████████| 6/6 [00:07<00:00,  1.26s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:09<00:00,  1.13s/it]
# Processing lines: 100%|█████████████████████████| 11/11 [00:09<00:00,  1.16it/s]
# Processing lines: 100%|███████████████████████████| 6/6 [00:10<00:00,  1.69s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:08<00:00,  1.39s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:07<00:00,  1.07s/it]
# Processing lines: 100%|███████████████████████████| 9/9 [00:10<00:00,  1.14s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:10<00:00,  1.52s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:03<00:00,  2.27it/s]
# Processing lines: 100%|█████████████████████████| 12/12 [00:07<00:00,  1.55it/s]
# Processing lines: 100%|█████████████████████████| 12/12 [00:09<00:00,  1.26it/s]
# Processing lines: 100%|█████████████████████████| 11/11 [00
/s]
# Processing lines: 100%|█████████████████████████| 10/10 [00:10<00:00,  1.05s/it]
# Processing lines: 100%|█████████████████████████| 13/13 [00:09<00:00,  1.33it/s]
# Processing lines: 100%|███████████████████████████| 7/7 [00:06<00:00,  1.04it/s]
# Processing lines: 100%|█████████████████████████| 13/13 [00:09<00:00,  1.31it/s]
# Processing lines: 100%|█████████████████████████| 13/13 [00:09<00:00,  1.36it/s]
# Processing lines: 100%|███████████████████████████| 3/3 [00:03<00:00,  1.23s/it]
# Processing lines: 100%|███████████████████████████| 9/9 [00:09<00:00,  1.07s/it]
# Processing lines: 100%|█████████████████████████| 11/11 [00:09<00:00,  1.15it/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:07<00:00,  1.07it/s]
# Processing lines: 100%|███████████████████████████| 6/6 [00:07<00:00,  1.25s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:09<00:00,  1.54s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:10<00:00,  1.32s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:08<00:00,  1.21s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:13<00:00,  1.66s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:10<00:00,  1.35s/it]
# Processing lines: 100%|█████████████████████████| 16/16 [00:18<00:00,  1.16s/it]
# Processing lines: 100%|█████████████████████████| 10/10 [00:08<00:00,  1.21it/s]
# Processing lines: 100%|███████████████████████████| 5/5 [00:04<00:00,  1.09it/s]
# Processing lines: 100%|███████████████████████████| 7/7 [00:07<00:00,  1.01s/it]
# Processing lines: 100%|█████████████████████████| 12/12 [00:09<00:00,  1.24it/s]
# Processing lines: 100%|███████████████████████████| 6/6 [00:04<00:00,  1.27it/s]
# Processing lines: 100%|███████████████████████████| 9/9 [00:10<00:00,  1.15s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:10<00:00,  1.52s/it]
# Processing lines: 100%|███████████████████████████| 9/9 [00:09<00:00,  1.09s/it]
# Processing lines: 100%|███████████████████████████| 9/9 [00:08<00:00,  1.12it/s]
# Processing lines: 100%|███████████████████████████| 7/7 [00:08<00:00,  1.21s/it]
# Processing lines: 100%|███████████████████████████| 5/5 [00:07<00:00,  1.56s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:12<00:00,  1.75s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:08<00:00,  1.38s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:09<00:00,  1.60s/it]
# Processing lines: 100%|███████████████████████████| 5/5 [00:07<00:00,  1.43s/it]
# Processing lines: 100%|███████████████████████████| 4/4 [00:13<00:00,  3.35s/it]
# Processing lines: 100%|███████████████████████████| 1/1 [00:12<00:00, 12.76s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:11<00:00,  1.57s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:09<00:00,  1.50s/it]
# Processing lines: 100%|███████████████████████████| 2/2 [00:11<00:00,  5.59s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:10<00:00,  1.75s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:11<00:00,  1.58s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:07<00:00,  1.01it/s]
# Processing lines: 100%|███████████████████████████| 3/3 [00:09<00:00,  3.12s/it]
# Processing lines: 100%|███████████████████████████| 8/8 [00:09<00:00,  1.24s/it]
# Processing lines: 100%|███████████████████████████| 9/9 [00:05<00:00,  1.51it/s]
# Processing lines:  11%|███                        | 1/9 [00:00<00:03,  2.21it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 86
#      84 cleaned_lines = []
#      85 for line in tqdm(lines, desc="Processing lines"):
# ---> 86     cleaned_line = clean_line(line)
#      87     if cleaned_line:  # None 체크
#      88         cleaned_lines.append(cleaned_line)
#
# Cell In[1], line 61, in clean_line(line)
#      59 cleaned_line = preprocess_text(line)
#      60 cleaned_line = remove_stopwords(cleaned_line)
# ---> 61 cleaned_line = correct_spelling(cleaned_line)
#      62 cleaned_line = stem_and_lemmatize(cleaned_line)
#      63 cleaned_line = filter_by_length(cleaned_line)
#
# Cell In[1], line 48, in correct_spelling(text)
#      46 def correct_spelling(text):
#      47     words = word_tokenize(text)
# ---> 48     corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
#      49     return ' '.join(corrected_words)
#
# Cell In[1], line 48, in <listcomp>(.0)
#      46 def correct_spelling(text):
#      47     words = word_tokenize(text)
# ---> 48     corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
#      49     return ' '.join(corrected_words)
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:158, in SpellChecker.correction(self, word)
#     151 """The most probable correct spelling for the word
#     152
#     153 Args:
#     154     word (str): The word to correct
#     155 Returns:
#     156     str: The most likely candidate or None if no correction is present"""
#     157 word = ensure_unicode(word)
# --> 158 candidates = self.candidates(word)
#     159 if not candidates:
#     160     return None
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:185, in SpellChecker.candidates(self, word)
#     183 # if still not found, use the edit distance 1 to calc edit distance 2
#     184 if self._distance == 2:
# --> 185     tmp = self.known(list(self.__edit_distance_alt(res)))
#     186     if tmp:
#     187         return tmp
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:252, in SpellChecker.__edit_distance_alt(self, words)
#     250 tmp_words = [ensure_unicode(w) for w in words]
#     251 tmp = [w if self._case_sensitive else w.lower() for w in tmp_words if self._check_if_should_check(w)]
# --> 252 return [e2 for e1 in tmp for e2 in self.known(self.edit_distance_1(e1))]
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:252, in <listcomp>(.0)
#     250 tmp_words = [ensure_unicode(w) for w in words]
#     251 tmp = [w if self._case_sensitive else w.lower() for w in tmp_words if self._check_if_should_check(w)]
# --> 252 return [e2 for e1 in tmp for e2 in self.known(self.edit_distance_1(e1))]
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:227, in SpellChecker.edit_distance_1(self, word)
#     225 deletes = [L + R[1:] for L, R in splits if R]
#     226 transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
# --> 227 replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
#     228 inserts = [L + c + R for L, R in splits for c in letters]
#     229 return set(deletes + transposes + replaces + inserts)
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:227, in <listcomp>(.0)
#     225 deletes = [L + R[1:] for L, R in splits if R]
#     226 transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R) > 1]
# --> 227 replaces = [L + c + R[1:] for L, R in splits if R for c in letters]
#     228 inserts = [L + c + R for L, R in splits for c in letters]
#     229 return set(deletes + transposes + replaces + inserts)
#
# KeyboardInterrupt:

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from spellchecker import SpellChecker
from tqdm import tqdm

# NLTK 리소스 다운로드
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

# 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = text.lower()
    return text

# 불용어 제거 함수
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    words = word_tokenize(text)
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 어간 추출 및 표제어 추출 함수
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = word_tokenize(text)
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 철자 검사 및 수정 함수
spell = SpellChecker()

def correct_spelling(text):
    words = word_tokenize(text)
    corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
    return ' '.join(corrected_words)

# 단어 수 세기 함수
def count_words(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    words = text.split()
    return len(words)

# 데이터 정화 및 복구 함수
def clean_line(line):
    cleaned_line = preprocess_text(line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    return cleaned_line

# 파일에서 데이터 읽기
file_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia.txt/processed_wikipedia.txt'

# 파일의 총 줄 수 계산
with open(file_path, 'r', encoding='utf-8') as file:
    total_lines = sum(1 for line in file)

# 결과를 저장할 파일 열기
output_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia_cleaned.txt'
with open(output_path, 'w', encoding='utf-8') as output_file:

    # 청크 단위로 데이터를 읽고 처리
    chunk_size = 1000
    total_processed_lines = 0
    processed_word_count = 0

    with open(file_path, 'r', encoding='utf-8') as file:
        with tqdm(total=total_lines, desc="Total Progress") as pbar:
            while True:
                lines = file.readlines(chunk_size)
                if not lines:
                    break

                cleaned_lines = []
                for line in tqdm(lines, desc="Processing lines", leave=False):
                    cleaned_line = clean_line(line)
                    if cleaned_line:  # None 체크
                        cleaned_lines.append(cleaned_line)

                # 처리된 데이터의 단어 수 계산
                processed_text = ' '.join(cleaned_lines)
                processed_word_count += count_words(processed_text)

                # 결과를 파일에 저장
                for cleaned_line in cleaned_lines:
                    output_file.write(cleaned_line + '\n')

                total_processed_lines += len(lines)
                pbar.update(len(lines))

print(f"Total lines processed: {total_processed_lines}")
print(f"Processed word count: {processed_word_count}")

# 상위 10개의 데이터 출력
with open(output_path, 'r', encoding='utf-8') as file:
    print("Top 10 cleaned data samples:")
    for i in range(10):
        print(f"{i+1}: {file.readline().strip()}")

print(f"\nData cleaned and saved to {output_path}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eternal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eternal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/eternal/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Total Progress:   0%|                             | 0/105502474 [00:00<?, ?it/s]
# Processing lines:   0%|                                   | 0/8 [00:00<?, ?it/s]
# Processing lines:  12%|███▍                       | 1/8 [00:01<00:12,  1.82s/it]
# Processing lines:  25%|██████▊                    | 2/8 [00:02<00:06,  1.13s/it]
# Processing lines:  38%|██████████▏                | 3/8 [00:03<00:04,  1.06it/s]
# Processing lines:  50%|█████████████▌             | 4/8 [00:04<00:04,  1.01s/it]
# Processing lines:  62%|████████████████▉          | 5/8 [00:04<00:02,  1.18it/s]
# Processing lines:  75%|████████████████████▎      | 6/8 [00:05<00:01,  1.43it/s]
# Processing lines:  88%|███████████████████████▋   | 7/8 [00:05<00:00,  1.51it/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:07<00:00,  1.16it/s]
# Total Progress:   0%|               | 8/105502474 [00:07<26186:18:36,  1.12it/s]
# Processing lines:   0%|                                   | 0/8 [00:00<?, ?it/s]
# Processing lines:  12%|███▍                       | 1/8 [00:00<00:05,  1.30it/s]
# Processing lines:  25%|██████▊                    | 2/8 [00:03<00:10,  1.71s/it]
# Processing lines:  38%|██████████▏                | 3/8 [00:04<00:08,  1.60s/it]
# Processing lines:  50%|█████████████▌             | 4/8 [00:05<00:05,  1.34s/it]
# Processing lines:  62%|████████████████▉          | 5/8 [00:05<00:02,  1.09it/s]
# Processing lines:  75%|████████████████████▎      | 6/8 [00:06<00:01,  1.25it/s]
# Processing lines:  88%|███████████████████████▋   | 7/8 [00:07<00:00,  1.06it/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:09<00:00,  1
/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:07<00:00,  1.06s/it]
# Total Progress:   0%|             | 454/105502474 [07:52<27839:51:23,  1.05it/s]
# Processing lines:   0%|                                   | 0/8 [00:00<?, ?it/s]
# Processing lines:  12%|███▍                       | 1/8 [00:00<00:03,  1.92it/s]
# Processing lines:  25%|██████▊                    | 2/8 [00:01<00:05,  1.17it/s]
# Processing lines:  38%|██████████▏                | 3/8 [00:03<00:07,  1.49s/it]
# Processing lines:  50%|█████████████▌             | 4/8 [00:04<00:04,  1.22s/it]
# Processing lines:  62%|████████████████▉          | 5/8 [00:05<00:03,  1.14s/it]
# Processing lines:  75%|████████████████████▎      | 6/8 [00:06<00:02,  1.05s/it]
# Processing lines:  88%|███████████████████████▋   | 7/8 [00:07<00:00,  1.15it/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:09<00:00,  1.30s/it]
# Total Progress:   0%|             | 462/105502474 [08:01<29760:28:51,  1.02s/it]
# Processing lines:   0%|                                   | 0/8 [00:00<?, ?it/s]
# Processing lines:  12%|███▍                       | 1/8 [00:00<00:05,  1.26it/s]
# Processing lines:  25%|██████▊                    | 2/8 [00:01<00:03,  1.64it/s]
# Processing lines:  38%|██████████▏                | 3/8 [00:02<00:04,  1.24it/s]
# Processing lines:  50%|█████████████▌             | 4/8 [00:02<00:02,  1.85it/s]
# Processing lines:  62%|████████████████▉          | 5/8 [00:03<00:02,  1.45it/s]
# Processing lines:  75%|████████████████████▎      | 6/8 [00:03<00:01,  1.67it/s]
# Processing lines:  88%|███████████████████████▋   | 7/8 [00:04<00:00,  1.82it/s]
# Processing lines: 100%|███████████████████████████| 8/8 [00:08<00:00,  1.85s/it]
# Total Progress:   0%|             | 470/105502474 [08:10<30656:14:25,  1.05s/it]
# Processing lines:   0%|                                  | 0/10 [00:00<?, ?it/s]
# Processing lines:  10%|██▌                       | 1/10 [00:01<00:09,  1.10s/it]
# Processing lines:  20%|█████▏                    | 2/10 [00:02<00:08,  1.02s/it]
# Processing lines:  30%|███████▊                  | 3/10 [00:02<00:05,  1.38it/s]
# Processing lines:  40%|██████████▍               | 4/10 [00:03<00:04,  1.48it/s]
# Processing lines:  50%|█████████████             | 5/10 [00:03<00:02,  1.81it/s]
# Processing lines:  60%|███████████████▌          | 6/10 [00:04<00:02,  1.70it/s]
# Processing lines:  70%|██████████████████▏       | 7/10 [00:04<00:01,  1.99it/s]
# Processing lines:  80%|████████████████████▊     | 8/10 [00:05<00:01,  1.33it/s]
# Processing lines:  90%|███████████████████████▍  | 9/10 [00:06<00:00,  1.52it/s]
# Processing lines: 100%|█████████████████████████| 10/10 [00:08<00:00,  1.07s/it]
# Total Progress:   0%|             | 480/105502474 [08:18<28187:14:53,  1.04it/s]
# Processing lines:   0%|                                  | 0/10 [00:00<?, ?it/s]
# Processing lines:  10%|██▌                       | 1/10 [00:01<00:14,  1.58s/it]
# ...
# Total Progress:   0%|             | 803/105502474 [14:24<35170:59:20,  1.20s/it]
# Processing lines:   0%|                                   | 0/7 [00:00<?, ?it/s]
# Processing lines:  14%|███▊                       | 1/7 [00:03<00:18,  3.15s/it]
# Processing lines:  29%|███████▋                   | 2/7 [00:05<00:12,  2.41s/it]
# Processing lines:  43%|███████████▌               | 3/7 [00:05<00:06,  1.57s/it]
# Processing lines:  57%|███████████████▍           | 4/7 [00:06<00:03,  1.16s/it]
# Processing lines:  71%|███████████████████▎       | 5/7 [00:07<00:02,  1.18s/it]
# Processing lines:  86%|███████████████████████▏   | 6/7 [00:08<00:00,  1.00it/s]
/s]
# Processing lines: 100%|█████████████████████████| 10/10 [00:09<00:00,  1.13it/s]
# Total Progress:   0%|             | 874/105502474 [15:53<33339:39:25,  1.14s/it]
# Processing lines:   0%|                                   | 0/4 [00:00<?, ?it/s]
# Processing lines:  25%|██████▊                    | 1/4 [00:01<00:03,  1.30s/it]
# Processing lines:  50%|█████████████▌             | 2/4 [00:02<00:02,  1.17s/it]
# Processing lines:  75%|████████████████████▎      | 3/4 [00:03<00:01,  1.16s/it]
# Processing lines: 100%|███████████████████████████| 4/4 [00:06<00:00,  1.91s/it]
# Total Progress:   0%|             | 878/105502474 [16:00<36072:02:51,  1.23s/it]
# Processing lines:   0%|                                   | 0/9 [00:00<?, ?it/s]
# Processing lines:  11%|███                        | 1/9 [00:01<00:09,  1.14s/it]
# Processing lines:  22%|██████                     | 2/9 [00:02<00:07,  1.12s/it]
# Processing lines:  33%|█████████                  | 3/9 [00:02<00:05,  1.15it/s]
# Processing lines:  44%|████████████               | 4/9 [00:03<00:04,  1.19it/s]
# Processing lines:  56%|███████████████            | 5/9 [00:04<00:02,  1.34it/s]
# Processing lines:  67%|██████████████████         | 6/9 [00:05<00:02,  1.07it/s]
# Processing lines:  89%|████████████████████████   | 8/9 [00:07<00:00,  1.18it/s]
# Processing lines: 100%|███████████████████████████| 9/9 [00:08<00:00,  1.07it/s]
# Total Progress:   0%|             | 887/105502474 [16:08<32624:30:03,  1.11s/it]
# Processing lines:   0%|                                  | 0/10 [00:00<?, ?it/s]
# Processing lines:  10%|██▌                       | 1/10 [00:00<00:04,  2.07it/s]
# Processing lines:  20%|█████▏                    | 2/10 [00:01<00:05,  1.56it/s]
# Processing lines:  30%|███████▊                  | 3/10 [00:01<00:03,  2.05it/s]
# Processing lines:  40%|██████████▍               | 4/10 [00:01<00:02,  2.59it/s]
# Processing lines:  50%|█████████████             | 5/10 [00:04<00:06,  1.32s/it]
# Processing lines:  60%|███████████████▌          | 6/10 [00:07<00:06,  1.71s/it]
# Processing lines:  80%|████████████████████▊     | 8/10 [00:07<00:02,  1.03s/it]
# Processing lines:  90%|███████████████████████▍  | 9/10 [00:08<00:00,  1.22it/s]
# Processing lines: 100%|█████████████████████████| 10/10 [00:08<00:00,  1.28it/s]
# Total Progress:   0%|             | 897/105502474 [16:17<30068:02:31,  1.03s/it]
# Processing lines:   0%|                                   | 0/5 [00:00<?, ?it/s]
# Processing lines:  20%|█████▍                     | 1/5 [00:00<00:02,  1.67it/s]
# Processing lines:  40%|██████████▊                | 2/5 [00:02<00:03,  1.20s/it]
# Processing lines:  60%|████████████████▏          | 3/5 [00:03<00:02,  1.13s/it]
# Processing lines:  80%|█████████████████████▌     | 4/5 [00:04<00:01,  1.33s/it]
# Processing lines: 100%|███████████████████████████| 5/5 [00:06<00:00,  1.34s/it]
# Total Progress:   0%|             | 902/105502474 [16:23<31440:30:59,  1.07s/it]
# Processing lines:   0%|                                   | 0/8 [00:00<?, ?it/s]
# Processing lines:  12%|███▍                       | 1/8 [00:00<00:03,  1.88it/s]
# Processing lines:  25%|██████▊                    | 2/8 [00:02<00:08,  1.48s/it]
# Processing lines:  50%|█████████████             | 5/10 [00:03<00:03,  1.46it/s]
# Processing lines:  60%|███████████████▌          | 6/10 [00:04<00:03,  1.06it/s]
# Processing lines:  70%|██████████████████▏       | 7/10 [00:05<00:02,  1.03it/s]
# Processing lines:  80%|████████████████████▊     | 8/10 [00:05<00:01,  1.35it/s]
# Processing lines:  90%|███████████████████████▍  | 9/10 [00:07<00:00,  1.01it/s]
# Processing lines: 100%|█████████████████████████| 10/10 [00:10<00:00,  1.61s/it]
# Total Progress:   0%|             | 943/105502474 [17:06<30211:26:28,  1.03s/it]
# Processing lines:   0%|                                   | 0/7 [00:00<?, ?it/s]
# Processing lines:  14%|███▊                       | 1/7 [00:01<00:11,  1.96s/it]
# Processing lines:  29%|███████▋                   | 2/7 [00:03<00:08,  1.68s/it]
# Processing lines:  43%|███████████▌               | 3/7 [00:05<00:07,  1.79s/it]
# Processing lines:  57%|███████████████▍           | 4/7 [00:07<00:05,  1.89s/it]
# Processing lines:  71%|███████████████████▎       | 5/7 [00:07<00:02,  1.37s/it]
# Processing lines:  86%|███████████████████████▏   | 6/7 [00:10<00:01,  1.79s/it]
# Processing lines: 100%|███████████████████████████| 7/7 [00:12<00:00,  2.01s/it]
# Total Progress:   0%|             | 950/105502474 [17:18<36532:22:59,  1.25s/it]
# Processing lines:   0%|                                   | 0/6 [00:00<?, ?it/s]
# Processing lines:  17%|████▌                      | 1/6 [00:00<00:04,  1.22it/s]
# Processing lines:  33%|█████████                  | 2/6 [00:00<00:01,  2.26it/s]
# Processing lines:  50%|█████████████▌             | 3/6 [00:03<00:03,  1.18s/it]
# Processing lines:  67%|██████████████████         | 4/6 [00:04<00:02,  1.13s/it]
# Processing lines:  83%|██████████████████████▌    | 5/6 [00:06<00:01,  1.41s/it]
# Processing lines: 100%|███████████████████████████| 6/6 [00:08<00:00,  1.70s/it]
# Total Progress:   0%|             | 956/105502474 [17:27<37473:14:41,  1.28s/it]
# Processing lines:   0%|                                  | 0/10 [00:00<?, ?it/s]
# Processing lines:  10%|██▌                       | 1/10 [00:01<00:09,  1.05s/it]
# Processing lines:  20%|█████▏                    | 2/10 [00:01<00:05,  1.40it/s]
# Processing lines:  30%|███████▊                  | 3/10 [00:02<00:04,  1.44it/s]
# Processing lines:  40%|██████████▍               | 4/10 [00:02<00:03,  1.84it/s]

# %%
import re
import pandas as pd
from nltk.corpus import stopwords
from spellchecker import SpellChecker
from tqdm import tqdm
import nltk

# NLTK stopwords 다운로드
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# 정규 표현식을 사용한 텍스트 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)  # HTML 태그 제거
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # 알파벳과 숫자, 공백을 제외한 모든 문자 제거
    text = re.sub(r'\s+', ' ', text)  # 다중 공백을 단일 공백으로 변경
    text = text.lower()  # 소문자 변환
    return text

# 불용어 제거 함수
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 철자 검사 및 수정 함수
spell = SpellChecker()
def correct_spelling(text):
    words = text.split()
    corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
    return ' '.join(corrected_words)

# 어간 추출 및 표제어 추출 함수
from nltk.stem import PorterStemmer, WordNetLemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = text.split()
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 데이터 정화 및 복구 함수
def clean_line(line):
    cleaned_line = preprocess_text(line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    return cleaned_line

def process_chunk(chunk):
    cleaned_lines = [clean_line(line) for line in chunk]
    return [line for line in cleaned_lines if line is not None]

# 파일에서 데이터 읽기
file_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia.txt/processed_wikipedia.txt'

# 파일의 총 줄 수 계산
with open(file_path, 'r', encoding='utf-8') as file:
    total_lines = sum(1 for line in file)

# 결과를 저장할 파일 열기
output_path = '/media/eternal/5TB HDD/sogang-nlp-rag/processed_wikipedia_cleaned.txt'

chunk_size = 10000  # 청크 크기를 줄여서 메모리 사용 최적화

def chunk_reader(file, chunk_size):
    while True:
        lines = file.readlines(chunk_size)
        if not lines:
            break
        yield lines

with open(output_path, 'w', encoding='utf-8') as output_file:
    with open(file_path, 'r', encoding='utf-8') as file:
        with tqdm(total=total_lines, desc="Total Progress") as pbar:
            for chunk in chunk_reader(file, chunk_size):
                cleaned_lines = process_chunk(chunk)
                for cleaned_line in cleaned_lines:
                    output_file.write(cleaned_line + '\n')
                pbar.update(len(cleaned_lines))

print(f"Data cleaned and saved to {output_path}")

# %%
import re
import pandas as pd
from nltk.corpus import stopwords
from spellchecker import SpellChecker
from tqdm import tqdm
import nltk
from concurrent.futures import ThreadPoolExecutor, as_completed
from multiprocessing import cpu_count

# NLTK stopwords 다운로드
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# 정규 표현식을 사용한 텍스트 전처리 함수
def preprocess_text(text):
    text = re.sub(r'<[^>]+>', '', text)  # HTML 태그 제거
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # 알파벳과 숫자, 공백을 제외한 모든 문자 제거
    text = re.sub(r'\s+', ' ', text)  # 다중 공백을 단일 공백으로 변경
    text = text.lower()  # 소문자 변환
    return text

# 불용어 제거 함수
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words]
    return ' '.join(filtered_words)

# 철자 검사 및 수정 함수
spell = SpellChecker()
def correct_spelling(text):
    words = text.split()
    corrected_words = [spell.correction(word) if spell.correction(word) else word for word in words]
    return ' '.join(corrected_words)

# 어간 추출 및 표제어 추출 함수
from nltk.stem import PorterStemmer, WordNetLemmatizer
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def stem_and_lemmatize(text):
    words = text.split()
    stemmed_words = [stemmer.stem(word) for word in words]
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

# 길이 필터링 함수
def filter_by_length(text, min_length=10):
    return text if len(text.split()) >= min_length else None

# 데이터 정화 및 복구 함수
def clean_line(line):
    cleaned_line = preprocess_text(line)
    cleaned_line = correct_spelling(cleaned_line)
    cleaned_line = remove_stopwords(cleaned_line)
    cleaned_line = stem_and_lemmatize(cleaned_line)
    cleaned_line = filter_by_length(cleaned_line)
    return cleaned_line

def process_chunk(chunk, pbar):
    cleaned_lines = [clean_line(line) for line in chunk]
    cleaned_lines = [line for line in cleaned_lines if line is not None]
    pbar.update(len(cleaned_lines))
    return cleaned_lines

# 파일에서 데이터 읽기
file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'

# 파일의 총 줄 수 계산
with open(file_path, 'r', encoding='utf-8') as file:
    total_lines = sum(1 for line in file)

# 결과를 저장할 파일 열기
output_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_cleaned.txt'

chunk_size = 10000  # 청크 크기를 줄여서 메모리 사용 최적화
num_workers = cpu_count()

def chunk_reader(file, chunk_size):
    while True:
        lines = file.readlines(chunk_size)
        if not lines:
            break
        yield lines

def process_and_write_chunks(chunks, output_file):
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        futures = []
        for chunk in chunks:
            pbar = tqdm(total=len(chunk), desc="Chunk Progress")
            futures.append(executor.submit(process_chunk, chunk, pbar))
        for future in as_completed(futures):
            cleaned_lines = future.result()
            for cleaned_line in cleaned_lines:
                output_file.write(cleaned_line + '\n')

if __name__ == '__main__':
    with open(output_path, 'w', encoding='utf-8') as output_file:
        with open(file_path, 'r', encoding='utf-8') as file:
            chunks = list(chunk_reader(file, chunk_size))
            with tqdm(total=total_lines, desc="Total Progress") as pbar:
                process_and_write_chunks(chunks, output_file)
                pbar.update(total_lines)

    print(f"Data cleaned and saved to {output_path}")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eternal/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Total Progress:   0%|                             | 0/105502474 [00:00<?, ?it/s]
# Chunk Progress:   0%|                                    | 0/79 [00:00<?, ?it/s]
#
# Chunk Progress:   0%|                                    | 0/70 [00:00<?, ?it/s]
#
#
# Chunk Progress:   0%|                                    | 0/83 [00:00<?, ?it/s]
#
#
#
# Chunk Progress:   0%|                                    | 0/63 [00:00<?, ?it/s]
#
#
#
#
# Chunk Progress:   0%|                                    | 0/61 [00:00<?, ?it/s]
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/60 [00:00<?, ?it/s]
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/71 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/53 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/64 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/70 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/65 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/71 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/65 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/74 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/54 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/56 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/70 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/77 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/86 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/82 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/67 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chunk Progress:   0%|                                    | 0/61 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# KeyboardInterrupt
