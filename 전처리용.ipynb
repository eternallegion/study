# %%
#커널폭파범

import json
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import logging

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# 모델과 토크나이저 초기화 (예: BERT 모델)
model_name = 'bert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name).to('cuda')

def extract_questions(input_file):
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    questions = [item['question'] for item in data]
    return questions

def preprocess_text(text):
    return text.lower().strip()

def encode_sentences(sentences):
    try:
        inputs = tokenizer(sentences, return_tensors='pt', padding=True, truncation=True).to('cuda')
        with torch.no_grad():
            outputs = model(**inputs)
        torch.cuda.empty_cache()  # GPU 메모리 해제
        return outputs.last_hidden_state.mean(dim=1).cpu().numpy()
    except Exception as e:
        logging.error(f"Error in encode_sentences: {e}")
        return np.zeros((len(sentences), 768))  # 에러 발생 시 기본값 반환

def find_similar_sentences(questions, sentences, threshold=0.7):
    question_encodings = encode_sentences(questions)
    sentence_encodings = encode_sentences(sentences)
    
    similar_sentences = {}
    for question, question_encoding in zip(questions, question_encodings):
        similarities = cosine_similarity([question_encoding], sentence_encodings)[0]
        similar_indices = np.where(similarities > threshold)[0]
        for idx in similar_indices:
            similar_sentences[sentences[idx]] = question
    
    return similar_sentences

def process_chunk(chunk, questions, threshold):
    try:
        similar_sentences = find_similar_sentences(questions, chunk, threshold)
        processed_chunk = []
        for sentence in chunk:
            if sentence in similar_sentences:
                preprocessed_sentence = preprocess_text(sentence)
                processed_chunk.append(f"{sentence} -> {preprocessed_sentence}")
            else:
                processed_chunk.append(sentence)
        return processed_chunk
    except Exception as e:
        logging.error(f"Error processing chunk: {e}")
        return chunk

def process_data_sequentially(input_file, text_file, output_file, chunk_size=100, threshold=0.7):
    questions = extract_questions(input_file)
    
    with open(text_file, 'r', encoding='utf-8') as f:
        original_text = f.read()
    
    sentences = original_text.split('. ')
    processed_text = []
    
    for i in range(0, len(sentences), chunk_size):
        chunk = sentences[i:i + chunk_size]
        processed_chunk = process_chunk(chunk, questions, threshold)
        processed_text.extend(processed_chunk)
        logging.info(f"Processed chunk {i // chunk_size + 1}/{len(sentences) // chunk_size + 1}")
    
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write('. '.join(processed_text))
# 파일 경로 설정
input_file = '/home/eternal/qa_train.json'
text_file = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file = '/home/eternal/processed_large_text_file.txt'

# 데이터 처리 실행
process_data_sequentially(input_file, text_file, output_file)

# %%
input_file = '/home/eternal/qa_train.json'
import json
with open(input_file) as f:
        data = json.load(f)
data
# Out:
# [{'answer': '1966',
#   'question': 'In what year the the venue that Marcia White is president of open?'},
#  {'answer': 'Portugal',
#   'question': 'What country is home to the sports club loaning Bruno Paulista to Vasco da Gama?'},
#  {'answer': 'Jerry Clower',
#   'question': '"Southern Air" featured Ray Stevens, Minnie Pearl and what other Southern comedian?'},
#  {'answer': 'Neshnabé',
#   'question': 'The Treaty of Prairie du Chien may refer to any of several treaties made between the United States and representatives from the native american people who called themselves what?'},
#  {'answer': 'writer',
#   'question': 'What profession do Thomas Merton and Michael Moorcock have in common?'},
#  {'answer': 'Carlo Rovelli',
#   'question': 'Who was the first person to describe Relational Quantum mechanics and has worked in Italy, the United States, and France?'},
#  {'answer': 'Branson, Missouri',
#   'question': 'Where is the Silver Dollar city theme park with the Grand exposition  steel roller coaster located?'},
#  {'answer': 'Pharrell Lanscilo Williams',
#   'question': 'Finna Get Loose is a song by Puff Daddy and what American rapper who is also a record and film producer?'},
#  {'answer': 'Cashel', 'question': 'What town is Hore Abbey located near?'},
#  {'answer': '1973',
#   'question': 'In what year was the actress who was starred in "The Telling" with Holly Madison born?'},
#  {'answer': 'the Russian Empire and the Empire of Japan',
#   'question': 'This war in which the Japanese cruiser Tokiwa played a large part was fought between which two groups?'},
#  {'answer': 'World Albums Chart',
#   'question': ' JJ Project was formed by JYP Entertainment and debuted as a part of a seven member group whose first EP peak at number one on which "Billboards" chart?'},
#  {'answer': 'July 23, 1993',
#   'question': 'When did the father of the principal owner and chairman of the Charlotte Hornets pass away?'},
#  {'answer': '10,254',
#   'question': 'In 2010 how many residents in the town of Watervliet were relying on the Normans Kill Creek to supply the Watervliet Reservior?'},
#  {'answer': 'Out of Place',
#   'question': 'Which film was produced in America, Time Bombs or Out of Place?'},
#  {'answer': 'Nelson County',
#   'question': 'Fighting Cock is produced in what Kentucky county?'},
#  {'answer': 'The Rocky Horror Picture Show',
#   'question': 'liver Twist is a 1982 made-for-TV adaptation starring an English actor who rose to prominence with his portrayal of Dr. Frank-N-Furter in what?'},
#  {'answer': 'Masdevallia',
#   'question': 'Is Masdevallia or Milium named after Jose Masdeval? '},
#  {'answer': 'The Stanley Brothers',
#   'question': 'Which members of The Clinch Mountain Boys released a recording of "Molly and Tenbrooks" in 1948?'},
#  {'answer': "Landry's, Inc.",
#   'question': 'Who owns the property where Matt Marcy was an opening act on the Fremont Street Experience?'},
#  {'answer': 'Authentic Trappist Product',
#   'question': 'What product from Orval Abbey is also sold in Belgium and the United States?'},
#  {'answer': 'The Fault in Our Stars',
#   'question': 'Which 2014 American romantic drama film was directed by Josh Boone and featured the Ed Sheeran song "All of the Stars" over the credits?'},
#  {'answer': 'Brandon Lee',
#   'question': 'Who son of Bruce Lee starred in Showdown in Little Tokyo'},
#  {'answer': 'Germany',
#   'question': 'What country shares a connection with the 2006 DFB-Pokal Final and the footballer Claudio Pizarro, who plays as a striker in the Bundesliga?'},
#  {'answer': 'Michael Showalter',
#   'question': 'Who directed The Big Sick, a 2017 romantic comedy film co-written by Emily Vance Gordan?'},
#  {'answer': 'Against Me!',
#   'question': 'Who has recorded more albums, Sunny Day Real Estate or Against Me!?'},
#  {'answer': 'naturalised',
#   'question': 'In differential geometry, a Nadirashvili surface is an immersed complete bounded minimal surface in R with negative curvature, Eugenio Calabi and Shing-Tung Yau had a question, about whether there was an immersed complete bounded minimal surface in R, Shing-Tung Yau is from Hong Kong and what type of American mathematician?'},
#  {'answer': 'Kingdom of Denmark',
#   'question': 'The Frogman Corps is the maritime special operations force of the unified armed forces of what kingdom?'},
#  {'answer': 'China',
#   'question': 'In which country will you find the county-level city Gaozhou and the Jiangdu District which was formerly a county-level city?'},
#  {'answer': 'Bellator MMA',
#   'question': 'Rocky Johnson is most notable for his win by submission over an American mixed martial artist who competes for who?'},
#  {'answer': 'Sir Nicholas Raymond Winterton',
#   'question': 'Which Member of Parliament for Macclesfield was married to Jane Ann Winterton?'},
#  {'answer': 'Diamonds',
#   'question': 'What song from Rihanna\'s album "Unapologetic" did pianist Tokio Myers play in semi-final 3 of the 2017 reality show "Britain\'s Got Talent"?'},
#  {'answer': 'Honeysuckle',
#   'question': 'Which genus has more species, Quesnelia or Honeysuckle?'},
#  {'answer': 'Cleveland, Ohio',
#   'question': 'William Aulton Kennedy was a pitcher for the Cleveland Indians, St. Louis Browns, Chicago White Sox, Boston Red Sox and Cincinnati Redlegs, what US city are the Cleveland Indians based out of?'},
#  {'answer': 'director',
#   'question': 'What type of profession does Charles Maigne and Stanley Kwan have in common?'},
#  {'answer': 'Anthony Eden',
#   'question': 'What 1st Earl of Avon also signed the Anglo-Soviet Treaty of 1942?'},
#  {'answer': 'Jeanne DuPrau',
#   'question': ' Gil Kenan worked on Monster House as well as another movie based on a Novel by which author?'},
#  {'answer': 'flowering plant',
#   'question': 'Sanguinaria and Stachyurus, are a genus of which type?'},
#  {'answer': 'The AD60 class',
#   'question': 'What class was 6029,a four-cylinder, simple, non-condensing, coal-fired superheated, 4-8-4+4-8-4 heavy goods steam locomotives built by Beyer, Peacock and Company for the New South Wales Government Railways in Australia, used in?'},
#  {'answer': 'Ring of Honor (ROH)',
#   'question': "Where does the Cody Taylor Hall's wrestling group notably appeared in USA?"},
#  {'answer': '1985',
#   'question': 'Julie Louise Gerberding was the administrator of federal public health agency formally organized in what yaer?'},
#  {'answer': 'best known for translating the work of Erich Maria Remarque',
#   'question': 'What German is Arthur Wesley Wheen best known for translating?'},
#  {'answer': 'Kevin Warren Sumlin',
#   'question': 'Dana Holgorsen served under what coach that was at the University of Houston from 2007 to 2011?'},
#  {'answer': 'New York City',
#   'question': 'Where did the director of the film Three Blind Mice relocate to from Australia?'},
#  {'answer': '1963',
#   'question': 'Newburgh Mall was opened by the same people who own a mall outside of Philadelphia that opened in what year?'},
#  {'answer': 'Károly Makk',
#   'question': 'Who had Five of his films nominated for the "Palme d\'Or" at the Cannes Film Festival, Károly Makk or Robert Stevenson?'},
#  {'answer': 'Béla Viktor János Bartók',
#   'question': 'Who was born first, Béla Bartók or Dmitri Shostakovich?'},
#  {'answer': 'Fallen',
#   'question': 'Which album, recorded between August and December 2002 in several locations, including Conway Recording Studios in Hollywood, California, features a track with uncredited guest vocals from Paul McCoy?'},
#  {'answer': 'Comandante',
#   'question': 'Which of the following is a documentary of interviews with Fidel Castro: Sweet Crude or Comandante?'},
#  {'answer': '101 Dalmatians',
#   'question': 'What film directed by Stephen Herek did an actor who appeared on Z-Cars and MacGyver also appear in?'},
#  {'answer': 'director',
#   'question': 'Lindsay Anderson and Alfonso Cuarón, share which common industry occupation?'},
#  {'answer': 'World War I',
#   'question': 'Louis Marshall supported a public statement issued by the British government during which war?'},
#  {'answer': 'Spain, Great Britain, France, Portugal, Savoy and the Dutch Republic',
#   'question': 'What states were involved in the 1713 radification of the Treaty of Utrecht?'},
#  {'answer': 'Kingdom Hearts',
#   'question': 'What s a series of crossover action role-playing games owned by Disney Interactive Studios, that had an English actress reprised her voice acting role s both Alice and Wendy in the 2002 video game?'},
#  {'answer': 'The Friday Times',
#   'question': "What is Jugnu Mohsin's husband the editor in chief of?"},
#  {'answer': 'Hobgoblin',
#   'question': 'Brakspear Brewery beers are principally brewed by a brewery whose flagship brand is what?'},
#  {'answer': 'enemy of the X-Men.',
#   'question': 'Who is Donald Pierce an enemy of?'},
#  {'answer': 'Swish Swish',
#   'question': 'Starrah co wrote what song for Katheryn Elizabeth Hudson ?'},
#  {'answer': '2 September 1989',
#   'question': "What is the birthdate of this Brazilian professional footballer, who was awarded the final Biodone d'Oro at the end of 2012?"},
#  {'answer': 'EBSCO Information Services',
#   'question': 'In the Library with the Lead Pipe, an academic journal on topics about libraries, is abstracted and indexed by this third largest private company in Birmingham, Alabama? '},
#  {'answer': 'Rod Stewart',
#   'question': 'What artist was knighted in 2016 and did the vocals for the band Python Lee Jackson?'},
#  {'answer': 'They Drive by Night',
#   'question': 'Whistle Stop starred an American film actor and dancer who played a truck driver in what movie?'},
#  {'answer': 'National Stock Exchange of India',
#   'question': 'Edelweiss Broking Limited registered with what stock exchange known for being the first exchange in India to offer a modern and fully automatic electronic trading system?'},
#  {'answer': 'yes',
#   'question': 'Did Richard Russo and Angela Davis write books?'},
#  {'answer': 'board game',
#   'question': 'Acquire and Torres, are which specific form of entertainment?'},
#  {'answer': 'no',
#   'question': 'Are  Platystemon and Apera part of the same genus?'},
#  {'answer': 'Beau Brummell',
#   'question': 'What iconic figure or Regency England also goes by the name of George Lashwood?'},
#  {'answer': '2010',
#   'question': 'The young captives is a movie by a director who passed away in which year ?'},
#  {'answer': 'Fredericton',
#   'question': 'What is the capital city in the province Azor LeBlanc represented? '},
#  {'answer': '1968',
#   'question': 'Subgenre of heavy metal, Neoclassical metal, was pioneered by an English rock band formed in Hertford in what year?'},
#  {'answer': '1840',
#   'question': 'The Violin Concerto No. 3 in E major was composed in 1826 by an Italian violinist who died in this year?'},
#  {'answer': 'Bundesliga',
#   'question': 'Where did an event take place resulting in a win during a domestic double due to the action of a Peruvian footballer known for his goal scoring ability?'},
#  {'answer': 'Los Angeles, California',
#   'question': 'Where is the residence of the "Proper Education" remixer known as Cirez D?'},
#  {'answer': 'Little Caesars Pizza',
#   'question': 'what is the third largest pizza chain in the united states that llitch holdings provides services for?'},
#  {'answer': 'Manu Ginóbili',
#   'question': 'Who is the professional player for the San Antonio spurs, who was also a shooting guard?'},
#  {'answer': 'Looney Tunes',
#   'question': 'Sylvester the Cat is part of what series of animated short films from Warner Bros.?'},
#  {'answer': 'Colonel Reb',
#   'question': 'Who did the Black Bear replace in 2010?'},
#  {'answer': 'Marvel Comics',
#   'question': 'The SAGA System is a role-playing game system that uses "fate cards" to determine the effects of actions, the system has been used in a TSR, Inc. game, and Marvel Super Heroes Adventure Game is a role-playing game published by TSR, Inc,not be confused with the later,"Marvel Universe Roleplaying Game", published by which organization?  '},
#  {'answer': 'Kneecapping',
#   'question': 'What was the malicious wounding that Andrew Kearney dead as a result?'},
#  {'answer': 'no',
#   'question': 'Was the Thomson TO7 introduced prior to the IMKO-1 computer?'},
#  {'answer': '1936',
#   'question': 'What year did the king die who signed the last of The Numbered treaties with the Aboriginal peoples in Canada?'},
#  {'answer': '320',
#   'question': 'How many people died in the event that is memorialized at  The Port Chicago Naval Magazine National Memorial?'},
#  {'answer': 'California',
#   'question': 'Otis Sistrunk played his entire NFL career with a team from what state?'},
#  {'answer': 'Trouble in Store',
#   'question': 'What was the film in which the star of  The Bulldog Breed had his first lead role ?'},
#  {'answer': 'yes',
#   'question': 'Are  Davallia and Fenestraria both names of plants?'},
#  {'answer': 'Switzerland',
#   'question': 'What country granted citizenship to the winning pair skating team of the 1971 Prize of Moscow News?'},
#  {'answer': 'Onnu Muthal Poojyam Vare',
#   'question': 'What movie is show in a the link language of Mahl-dominated Minicoy Island?'},
#  {'answer': 'M&T Bank Stadium',
#   'question': 'Where does the team which signed Kenny Wiggins in 2011 play its home games?'},
#  {'answer': 'American',
#   'question': 'What nationality are the opera singers Ronald Naldi and Samuel Ramey?'},
#  {'answer': 'Chvrches',
#   'question': 'Between The All-American Rejects and Chvrches, which band has Lauren Mayberry as its lead vocalist?'},
#  {'answer': '4,593',
#   'question': 'The town in which the Suncook Lakes is located had a population of what at the 2010 census?'},
#  {'answer': 'Sevendust',
#   'question': 'What Atlanta Georgia based alternative metal band has toured with Russian military style inspired Janus?'},
#  {'answer': 'gray wolf, dog or wolfdog',
#   'question': 'What type of animal was pursued and slain by Antoine De Beauterne ?'},
#  {'answer': 'no',
#   'question': 'Are Kenji Mizoguchi and David Wall from the same country?'},
#  {'answer': 'Kindergarten Cop',
#   'question': 'Which movie starred Arnold Schwarzenegger as a cop and Pamela Reed as his partner?'},
#  {'answer': 'Billy Boys',
#   'question': 'The Norman Conks (or Norman Conquerors) were a large Catholic sectarian street gang active in Glasgow, they were often involved in street fighting with which Protestant group, from Bridgeton, and is also a loyalist song, with a title of its same name, from Glasgow?'},
#  {'answer': 'The Suite Life of Zack & Cody',
#   'question': 'Candace Flynn was voiced by the actress who achieved mainstream success on what show?'},
#  {'answer': 'a Ghanaian boxer',
#   'question': 'The boxer that defeated Oliver Lavigilante in the 2012 Summer Olympics is of what nationality?'},
#  {'answer': '28 July 1914 to 11 November 1918',
#   'question': 'The 76-mm air-defense gun M1914/15 was an anti-aircraft gun used during a war that lasted during which dates?'},
#  {'answer': 'film',
#   'question': 'What type of media does The Good Dinosaur and The Three Lives of Thomasina have in common?'},
#  {'answer': '"In Another Land"',
#   'question': 'What is the third track on the Rolling Stones album that was the first to feature the same track listings in both its UK and US versions?'},
#  {'answer': 'commercial and music video director',
#   'question': 'Alek Keshishian and Tony Petrossian, have which mutual occupations?'},
#  {'answer': 'Arsenal',
#   'question': 'Which football club hosted the 2017 Emirates Cup which featured RB Leipzig?'},
#  {'answer': 'surgeon Major Frank Burns',
#   'question': 'What is the actor who starred in School Spirit best known for?'},
#  {'answer': 'South Korean actress', 'question': 'Who starred in The Musical?'},
#  {'answer': 'Jesse Plemons',
#   'question': 'Which Other People star was born on April second 1988?'},
#  {'answer': 'New York',
#   'question': "In what state's militia did the father of George W. Pratt serve during the Civil War?"},
#  {'answer': 'Aubrey Posen',
#   'question': 'What is the name of the character portrayed by Anna Camp in the film centered on the fictional Barden University and The Bellas?'},
#  {'answer': 'U.S. Route 81',
#   'question': 'Sunray is a community located south of which Route that was established in 1926?'},
#  {'answer': '1980',
#   'question': 'The director of The Wise Kids was born in what year?'},
#  {'answer': 'the Miami Dolphins',
#   'question': 'Mark Dixon was am offensive guard for what Florida AFC East Division team?'},
#  {'answer': 'American Academy of Arts and Sciences, the American Physical Society',
#   'question': 'Including the non-governmental organisation of experts committed to expanding the frontiers of space, what were the other two societies Loeb was elected fellow of?'},
#  {'answer': '2011 New England tornado outbreak',
#   'question': "Southbridge Municipal Airport (FAA LID: 3B0) is a public airport located two miles (3 km) north of the central business district (CBD) of the Town of Southbridge, a city in Worcester County, Massachusetts, USA, the airport sustained damage on June 1st, 2011, from which event, when seven tornadoes appeared in Massachusetts' Connecticut River Valley and southern Maine, destroying large sections of Springfield, Massachusetts and its surrounding region, killing three people ?"},
#  {'answer': 'Burton Memorial Baptist Church',
#   'question': 'Where was the man who converted Grady Wilson to evangelism ordained at? '},
#  {'answer': '"America\'s Greatest Family Newspaper"',
#   'question': ' Michael R. Rafferty served as an editor of a weekly newspaper that had what subtitle?'},
#  {'answer': 'United Methodist',
#   'question': 'The Draconic Prophecies is a series of books by a minister in what religion?'},
#  {'answer': 'yes',
#   'question': 'Was the band Tomahawk and the band The Amps both formed in the 90s?'},
#  {'answer': 'no',
#   'question': 'Are both Mimetes and Shortia a genus of subshrubs or perennial herbs?'},
#  {'answer': '703',
#   'question': ' UFC Fight Night: Silva vs. Irvin was held at a resort that has how many rooms and suites?'},
#  {'answer': 'Nisse',
#   'question': 'What is the nickname of the talisman who was part of the year that AIK only conceded 28 goals?'},
#  {'answer': 'no',
#   'question': 'We’re both Edward Albee and Arturo Uslar Pietri both politicians?'},
#  {'answer': 'American',
#   'question': "What is the nationality of the producer of the 2012 American survival drama film based on Yann Martel's 2001 novel?"},
#  {'answer': 'Hit Parader',
#   'question': 'What music magazine ran from 1942 to 2008 and had a compilation album "The Wild Bunch" in 1984?'},
#  {'answer': 'Ronald Bilius "Ron" Weasley',
#   'question': 'Joey Richter co-starred as which Harry Potter character in 2009 fan parody musicals?'},
#  {'answer': 'Bangor Air National Guard Base',
#   'question': 'What Air Base became an airport that is home to the 101st Air Refueling wing of the Maine Air National Guard?'},
#  {'answer': 'no',
#   'question': 'are Rika Hiraki and Mike Bryan from the same country'},
#  {'answer': '1956',
#   'question': 'The narrator of Inside Mecca was born in what year?'},
#  {'answer': 'Lawrence Livermore National Laboratory',
#   'question': 'Nova was a high-power laser built where?'},
#  {'answer': 'American',
#   'question': 'Of Pandas and People was written by an author of what nationality?'},
#  {'answer': 'neoceltic pagan folk',
#   'question': 'Ceasair and Omnia are examples of what type of music?'},
#  {'answer': '"Father Ted" and "The IT Crowd"',
#   'question': 'For what sitcoms did the man who formed The Duckworth Lewis Method write the theme tunes?'},
#  {'answer': 'Symplocos',
#   'question': 'Which is the only genus in family Symplocaceae, Acacia or Symplocos?'},
#  {'answer': 'Salta',
#   'question': 'What city in the Lerma Valley in the northwest part of Argentina was home to Miguel Ángel Biazzi for twenty years?'},
#  {'answer': 'England',
#   'question': 'What country is the birthplace of the author of the Method of Fluxions?'},
#  {'answer': 'no', 'question': 'Are Pylon and Team Sleep experimental bands?'},
#  {'answer': 'Second line',
#   'question': 'What type of tradition in brass band parades was performed by Brigade?'},
#  {'answer': '10 December 1822',
#   'question': 'When was the pianist who played the musical settings of  Les Sept Paroles du Christ sur la Croix born? '},
#  {'answer': 'Frank Lloyd Wright',
#   'question': 'Seamour and Gerte Shavin House was designed by which Welsh-American architect?'},
#  {'answer': 'The Matrix',
#   'question': 'Bruce Berman was a producer for which films made by the Wachowskis?'},
#  {'answer': 'River Dniester',
#   'question': 'Konstantin Kasimovsky became convinced of Nazism after a 1992 visit to a state that is located between Ukraine and what river?'},
#  {'answer': 'Sweetback',
#   'question': 'Paul S. Denam is a member of the band Sade but he is also a member of what other English band?'},
#  {'answer': 'Maurice Ravel',
#   'question': 'who was born first, Sergei Prokofiev or Maurice Ravel ?'},
#  {'answer': 'yes',
#   'question': 'are Peter Maxwell Davies and Emmanuel Chabrier both composers ?'},
#  {'answer': 'A.C. Slater',
#   'question': 'What character did the host of the Miss Teen USA 1998 pageant play in the TV series Saved by the Bell ?  '},
#  {'answer': 'yes',
#   'question': 'Do both groups, Chvrches and Anavae, feature a guitar?'},
#  {'answer': 'national historical landmark',
#   'question': 'What is the Culver Hotel which is located in Culver City, California?'},
#  {'answer': 'Mickey Rooney',
#   'question': 'What actor born Joseph Yule Jr. on September 23, 1920 was in the movie All Ashore by Richard Quine?'},
#  {'answer': '"Allegiance: A New American Musical"',
#   'question': 'The actor who portrayed Hikaru Sulu in Star Trek costared in which Broadway play with a founding member of the Asian American sketch comedy troupe 18 Mighty Mountain Warriors?'},
#  {'answer': '"Confessions of a Dangerous Mind"',
#   'question': 'The Bobby Vinton Show was created by Chris Bearde and packaged by a man that wrote what autobiography?'},
#  {'answer': 'state capital',
#   'question': ' Marion is approximately 50 mi north of a city that is the third-most populous what in the U.S.?'},
#  {'answer': '1995',
#   'question': 'Burning Inside, was an American death metal band, formed by ex-members of various other groups, it was formed in what year, by Steve Childers and Thomas Richard Christy Jr. (born April 1, 1974) is an American drummer, radio personality and actor, best known for being the former drummer for several heavy metal bands since the early 1990\'s and his tenure on "The Howard Stern Show"?'},
#  {'answer': "Scarlett O'Hara",
#   'question': 'Rhett is the official costumed mascot of the Boston University (BU) and the Boston University Academy (BUA) Terriers, the often snarling, bi-pedal black and white Boston Terrier was later named after the male lead in Margaret Mitchell\'s "Gone with the Wind", because "No one loves Scarlett more than Rhett" referencing Rhett Butler\'s affection for which fictional character and the main protagonist in Margaret Mitchell\'s 1936 novel "Gone with the Wind" and in the later film of the same name?'},
#  {'answer': 'quarterback',
#   'question': 'What position did Gary Danielson play in the National Football League?'},
#  {'answer': 'the Indo-Aryan branch',
#   'question': 'Which branch of the Indo-European language family does this language belong in which Kalyi Jag means "Black Fire?"'},
#  {'answer': 'Human Movement Science',
#   'question': 'The Pangaea Expedition is a worldwide voyage led by a South African-born Swiss adventurer who studied what at Stellenbosch University?'},
#  {'answer': 'The Chevrolet Aveo',
#   'question': 'What car manufactured by Daewoo was featured in the Chevrolet ad campaign know as An American Revolution?'},
#  {'answer': 'Friedrich Nietzsche',
#   'question': "Name the German philosopher, poet, and philologist whose novel inspired an oil painting cycle 'Also sprach Zarathustra' which was exhibited several times including Moscow in 2005?"},
#  {'answer': 'Ford County',
#   'question': 'Dodge City, through which U.S. Route 50 in Kansas runs, is the seat of what County?'},
#  {'answer': 'Enrico Cocozza',
#   'question': 'Who is scottish film maker, Torre Catalano or Enrico Cocozza?'},
#  {'answer': 'Sand Mountain',
#   'question': 'Lakeview, Alabama is located atop what part of the southern tip of the Appalachians?'},
#  {'answer': 'Matt Ryan',
#   'question': 'Charles Halford played Francis "Chas" Chandler in a tv series that stars what actor in the title role?'},
#  {'answer': 'Tim Duncan',
#   'question': 'Which National Basketball Association player played his entire career with the team that Gregg Popovich coached?'},
#  {'answer': "Hell's Kitchen",
#   'question': 'The museum for which Mike Massimino is the senior advisor of space programs for is located in which neighborhood on the West Side of Manhattan?'},
#  {'answer': 'British',
#   'question': 'Abi Morgan, writer of "Suffragette", is which nationality?'},
#  {'answer': 'yes',
#   'question': 'Are both Parsley and Stangeria considered species in the classification system?'},
#  {'answer': 'no',
#   'question': 'Do John Carl Buechler and Mikhail Romm share the same nationality?'},
#  {'answer': 'Rubén Darío',
#   'question': 'Who had more of an influence on Spanish literature, Jonathan Kellerman or Rubén Darío?'},
#  {'answer': 'Howard the Duck',
#   'question': 'Which movie starring Jordan Prentice was directed by Willard Huyuck?'},
#  {'answer': 'Angola',
#   'question': "Benjamin Ucuahamba, better known as Benjamin Avô, is a former Angolan basketball player, was born in Luanda, the capital and largest city in which country, and the country's most populous and important city, primary port and major industrial, cultural and urban centre?"},
#  {'answer': 'Union Canal',
#   'question': 'Which was built first, Union Canal or Columbia Canal?'},
#  {'answer': 'number 8',
#   'question': 'Chuck Berry House was where the 1957 hit single that reached what ranking on the R&B singles chart was composed?'},
#  {'answer': 'author',
#   'question': 'What is the occupation of both  Nelson DeMille and Imre Kertész?'},
#  {'answer': 'Provisional Irish Republican Army',
#   'question': 'Which group carried out the pub bombings that men such as Gerard "Gerry" Conlon were convicted of?'},
#  {'answer': 'dementia',
#   'question': 'What disease is the Wolf Prize winner and Vadim  Bereinskii-inspired Nobel laureate suffering from?'},
#  {'answer': 'Hertfordshire',
#   'question': 'Giorgio Mazzon, was born in Waltham Cross, located within the metropolitan area of London, the Greater London Urban Area, and the Borough of Broxbourne in where?'},
#  {'answer': 'Gaius Julius Caesar Germanicus',
#   'question': 'What was the birth name of the emperor under whom Naevius Sutorius Macro served as prefect of the Praetorian Guard?'},
#  {'answer': 'Pyrenean Mastiff',
#   'question': 'Which dog breed is generally larger, the Pyrenean Mastiff or West Highland White Terrier?'},
#  {'answer': 'Wilfred Edward Salter Owen',
#   'question': 'Which was a poet, Wilfred Owen or Ernst Toller?'},
#  {'answer': 'British Columbia',
#   'question': 'In what province is the airport that includes a hub for a low-cost alternative Candian Airline founded in 1996 located?'},
#  {'answer': 'Colorado Rockies',
#   'question': 'Which of the teams that Sun-woo Kim played on never won a division title?'},
#  {'answer': 'State of Maine',
#   'question': 'Where was Wyman B. S. Moor chief legal advisor?'},
#  {'answer': 'Alter Bridge',
#   'question': 'Ben Grosse produced an album for what band formed in 2004 in Orlando, Florida?'},
#  {'answer': 'Matthew Wayne "Matt" Shepard',
#   'question': "Who was Romaine Patterson's friend who was beaten, tortured, and left to die near Laramie?"},
#  {'answer': 'yes',
#   'question': 'Do the words Cymbidium and Prunus have to do with the plant kingdom?'},
#  {'answer': "Shaquille O'Neal",
#   'question': 'What is an American retired professional basketball player toured with LaVar Walker?'},
#  {'answer': 'October 14, 1943',
#   'question': 'When was the player whom the Los Angeles Rams traded William Frederick Traux for born?'},
#  {'answer': 'in his opinion, one of his best works',
#   'question': "What was Sartre's opinion on his novel which included the character The Autodidact?"},
#  {'answer': '1991',
#   'question': 'What year marked 3 consecutive wins for Stacey king?'},
#  {'answer': 'signed',
#   'question': 'What type of gesture does Donets-Krivoy Rog Soviet Republic and have in common?'},
#  {'answer': 'London',
#   'question': 'What country are Belgravia, and Knightsbridge are located in?'},
#  {'answer': '2003',
#   'question': 'Redcon-1 includes the co-producer who produced the American Hong Kong action comedy film released in what year?'},
#  {'answer': 'Palash Sen',
#   'question': 'Which member of India\'s pop band Euphoria appeared in the film "Filhaal...?"'},
#  {'answer': 'The Best Years of Our Lives',
#   'question': 'American film actor, Dana Andrews, starred in the 1943 American Western film The Ox-Bow Incident, however, he is most famous for his role as war veteran Fred Derry in what film?'},
#  {'answer': 'Nickolas Gene "Nick" Carter',
#   'question': 'Which singer is from country closer to Canada, Lovefoxxx or Nick Carter?'},
#  {'answer': '1837',
#   'question': 'New London is a census-designated place (CDP) and the primary village in the town of New London in Merrimack County, New Hampshire, United States, the CDP includes the campus of Colby–Sawyer College, a private, comprehensive baccalaureate college situated on a 200 acre campus in New London, in the Lake Sunapee region of New Hampshire, founded as a coeducational academy in which year?'},
#  {'answer': 'Xavier College',
#   'question': 'Which Roman Catholic day and boarding school did Simon Paul Whelan attend?'},
#  {'answer': 'Three',
#   'question': 'How man more Academy  Awards did the creator of Sylvester the Cat win than the creator of Flippity and Flop?'},
#  {'answer': 'Antônio Rogério Nogueira',
#   'question': 'Who is younger  Luiz Carlos Dórea or Antônio Rogério Nogueira ?'},
#  {'answer': 'English rock',
#   'question': 'Radiohead and Oceansize are bands that play which type of music?'},
#  {'answer': 'no',
#   'question': 'Are Youngstown State University and Marmara University in the same country?'},
#  {'answer': '1 February 1999',
#   'question': 'Air Nostrum, Líneas Aéreas del Mediterráneo, S.A., also known as Iberia Regional, is a regional airline based in Valencia, Spain, Iberia Regional franchise is a regional partner of Iberia and an affiliate member of Oneworld, an airline alliance, founded on which date?'},
#  {'answer': 'Bier and Anders Thomas Jensen',
#   'question': 'Brothers is a 2009 American psychological war drama film and a remake of a film written by what two people?'},
#  {'answer': 'Benjamin T. Orifici',
#   'question': 'Who has more scope of profession, Paul Czinner or Benjamin T. Orifici?'},
#  {'answer': 'Katja K',
#   'question': 'Nej til knive features voices of many actors and actresses, including that of what actress formerly known as Sussi la Cour?'},
#  {'answer': '1814',
#   'question': "Augustus d'Este was the grandson of a monarch who was promoted to King of Hanover in what year?"},
#  {'answer': 'Green Bay Packers',
#   'question': 'The state produced what player Brian Brohm, who was among the top 20 in his position, was drafted by what football team in the 2008 NFL Draft?'},
#  {'answer': 'Levon Helm',
#   'question': "Joan Baez's hit recording from Quad Studios Nashville originally featured lead vocals from what member of The Band?"},
#  {'answer': 'Ezra Matthew Miller',
#   'question': 'What actor who  made his feature film debut in the film "Afterschool" stared in a 2016 fantasy film directed by David Yates and stars Eddie Redmayne as Newt ?'},
#  {'answer': 'Egypt',
#   'question': 'Coptic nationalism is a belief system of a group of people who inhabit which modern-day nation?'},
#  {'answer': 'It is part of the Honghe Hani and Yi Autonomous Prefecture and borders the northern Vietnamese town of Lào Cai.',
#   'question': 'Which borders Vietnam, Hekou Yao Autonomous County or Lhasa City?'},
#  {'answer': '7 million to 10 million',
#   'question': 'Stanislav Kosior is known as one of the architects of the famine that killed an estimated how many people?'},
#  {'answer': '2011',
#   'question': 'Ikemen desu ne, released in which year, is a Japanese television series, it is the Japanese remake of the Korean musical romantic comedy television drama "You\'re Beautiful"?'},
#  {'answer': 'Jon Turteltaub',
#   'question': 'Who directed the 2010 movie with the English-American actor from Chocolat, Boogie Nights and Raiders of the Lost Ark?'},
#  {'answer': '1981 World Rowing Championships',
#   'question': 'Riema Juhani Karppinen won the silver medal at what event held outside of Munich, Germany?'},
#  {'answer': 'Zibo',
#   'question': "Is Zibo, the prefecture-level city, or Huaiyin District, Huai'an located in the central Shangong province, China?"},
#  {'answer': 'Steep Hill is a popular tourist street in the historic city of Lincoln',
#   'question': "In what location in Lincolnshire can you find the historic Jew's House?"},
#  {'answer': 'soprano',
#   'question': 'Jodi benson who voiced Ariel in all official appearances and merchandise is what kind of singer?'},
#  {'answer': 'Bernard Curry',
#   'question': 'which  Sydney-based Australian actor, hosted Monster House'},
#  {'answer': 'PJ Harvey',
#   'question': 'Who was the English alternative Rock Musician and songwriter who created the studio album Stories from the City, Stories from the Sea?'},
#  {'answer': 'no',
#   'question': 'Are both the  Bayezid II Mosque and the Eski Imaret Mosque intact?'},
#  {'answer': 'Arlington, Texas',
#   'question': "Cadillac's SUV for which there are no plans to create a V-Series model is built in what city and state?"},
#  {'answer': 'Monty Franklin Pierce Stratton',
#   'question': 'What MLB pitcher nicknamed "Gander" was written about in "the Stratton Story">?'},
#  {'answer': 'The Little Match Girl',
#   'question': "What is the name the Columbian film loosely based on a story about a dying child's dreams and hope first published in 1845 by Hans Christian Andersen?"},
#  {'answer': 'six',
#   'question': 'How many historic counties are there in the country in which Glencull is a townland?'},
#  {'answer': 'Chris Applebaum',
#   'question': 'What American music video director worked with the group previously known as 78violet?  '},
#  {'answer': 'Alden March and James H. Armsby',
#   'question': 'Henry Hun was a professor of Nervous Diseases at  a medical school founded by who ?'},
#  {'answer': 'United States',
#   'question': "The People's Political Party, (PPP) was Jamaica's first modern political party, formed in September 1929 by Marcus Mosiah Garvey Jr., was a proponent of Black nationalism in Jamaica and especially which location?"},
#  {'answer': 'Qing dynasty',
#   'question': 'The Broadway expedition occurred in a war during what dynasty of China?'},
#  {'answer': 'film director',
#   'question': 'What do Bruno Mattei and Andrés Wood have in common?'},
#  {'answer': 'One Hundred and One Dalmatians',
#   'question': 'Did Do Dooni Chaar or One Hundred and One Dalmatians come out first?'},
#  {'answer': '2006',
#   'question': 'The Korea American Football Association, has existed in South Korea for more than 20 years, the popularity of American football in Korea has been historically low, but with the visit of Hines Edward Ward Jr.a Korean born NFL football star, and television personality, with the Pittsburgh Steelers, in what year, the sport received a modest level of increased appeal?'},
#  {'answer': 'Lincoln Highway',
#   'question': 'What highway was conceived by Carl Fisher and had the Whitford Lodge located on it?'},
#  {'answer': 'Cryptotaenia',
#   'question': 'Which is endemic to Asia, Cryptotaenia or Bromelia?'},
#  {'answer': 'Amityville 3-D',
#   'question': 'Which 1983 supernatural horror film was based on the overview of noted paranormal investigator Stephen Kaplan?'},
#  {'answer': 'the richest living American',
#   'question': 'What was the American industrialist that founded an American oil marketing company named by a 1957 "Fortune" magazine?'},
#  {'answer': '98th',
#   'question': "What number season of the National Football League was Paul King the umpire on Ronald Torbert's crew?"},
#  {'answer': 'Mexico',
#   'question': 'Latin Classics Mijares featured compilations of artists whose company has exclusive rights in what country?'},
#  {'answer': 'Parícutin',
#   'question': 'What volcano surged suddenly from a cornfield and was filmed erupting during the filming of scenes in the movie Captain from Castile?'},
#  {'answer': 'writer',
#   'question': 'Wilhelm Reich and Jorge Luis Borges, have which occupation in common?'},
#  {'answer': 'Anna of the North',
#   'question': 'What Oslo based Norwegian singer-songwriter was featured in the fourth studio album by American rapper Tyler, the creator?'},
#  {'answer': 'Delamere Forest',
#   'question': 'Delamere railway station serves which large wood near Frodsham?'},
#  {'answer': 'the Belyayev circle',
#   'question': 'What society of musicians was founded by Mitrofan Belayev and included Russian composer Natoly Lyadov?'},
#  {'answer': 'Ira Levin',
#   'question': 'Carole Mallory, is an American author, actress, former model, teacher and critic who appeared in The Stepford Wives, a 1972 satirical thriller novel by who?'},
#  {'answer': 'Dart Container',
#   'question': 'Who now owns the company that was headed by Robert Leo "Bob" Hulseman until 2006?'},
#  {'answer': 'Valencia, California',
#   'question': 'Alan Schilke is an engineer who made is mark on a steel roller coaster operating at Six Flags Magic Mountain which is located where?'},
#  {'answer': 'Memorias',
#   'question': 'Name of autobiography written by advisor and confidant of Queen catalina of castile who  governed Castile as regent from 1406 until 1418 during the minority of her son.'},
#  {'answer': 'Dunscaith Castle',
#   'question': 'Which castle is named after an Irish legend warrior and is located on the Isle of Skye?'},
#  {'answer': 'Ghana',
#   'question': 'The Bawku municipal district is part of what region?'},
#  {'answer': 'Winston-Salem',
#   'question': 'Which North Carolina city is nicknamed "Camel City" after the local cigarette brand, formerly a big supporter of GT and other auto racing?'},
#  {'answer': 'The Black Cauldron',
#   'question': 'Princess Eilonwy, is a fictional character in Lloyd Alexander\'s "The Chronicles of Prydain", she also appears  in four of the five novels in the series, as well as Disney\'s 1985 animated film adaptation of which 1985 American animated dark fantasy adventure film?'},
#  {'answer': 'Bill Melendez',
#   'question': 'Who directed the movie that was commemorated on its 50th anniversary by "The Peanuts Movie"?'},
#  {'answer': 'no',
#   'question': 'Are the Garajonay National Park and Caldera de Taburiente National Park located on the same island?'},
#  {'answer': 'no',
#   'question': 'Are Stephens Cur and Smooth Collie both herding dogs?'},
#  {'answer': 'Chris Columbus',
#   'question': 'Jean Southern appeared as the lady who operates the trolley in a movie directed by who ?'},
#  {'answer': 'Adrien Philippe',
#   'question': 'Wincenty Gostkowski, was a lawyer and associate of Antoni Patek, and who?'},
#  {'answer': 'magazine', 'question': 'Lucky and Giant Robot were both what?'},
#  {'answer': 'KBS2',
#   'question': 'Han Chae-young was in the 2009 drama that aired on what network?'},
#  {'answer': 'Diana Freeman-Mitford',
#   'question': 'White is the birth name of the author of A Life Of Contrasts'},
#  {'answer': 'Mike Binder',
#   'question': 'Who wrote and directed a 2014 drama that featured the actor that played Patrick Kuby in "Breaking Bad"?'},
#  {'answer': 'Michael and Peter Spierig',
#   'question': 'Who directed the film for which  Matt Villa won his second AACTA Award ?'},
#  {'answer': 'Chief of Protocol',
#   'question': 'What government position was held by the woman who portrayed Corliss Archer in the film Kiss and Tell?'},
#  {'answer': '848',
#   'question': 'Matthew Butturini was born in a town on the Tweed River how many km north-east of Sydney?'},
#  {'answer': 'Bergen County',
#   'question': 'What is the most populous county in New Jersey and has Barnstable Academy as one of its institutions?'},
#  {'answer': 'novels or short stories',
#   'question': 'In this 2002 film the Apollo 11 Moon landing was faked and recorded in a studio by the CIA with help from a director whose film are mostly adaptations of what? '},
#  {'answer': 'six',
#   'question': 'The Case of: JonBenét Ramsey was a series about the beauty queen who was killed in 1996 at what age?'},
#  {'answer': '1988',
#   'question': 'In what year did Tony Lopez defeat the first boxer to defeat Roger Mayweather?'},
#  {'answer': '1939',
#   'question': 'Days of Wine and Roses and Other TV Requests includes songs such as the song by Jimmie Davis and was first recorded in what year?'},
#  {'answer': '1800',
#   'question': 'What year was the college founded that Simi Hamilton attended?'},
#  {'answer': 'National Field Director',
#   'question': 'Ready PAC was founded by the strategist who had what position for the Democratic National Committee?'},
#  {'answer': 'Big City Greens',
#   'question': 'Julia Kaye works on which upcoming Disney animated television series by Chris and Shane Houghton?'},
#  {'answer': 'Elizabeth Swann',
#   'question': 'Keira Knightley began acting as a child and had several supporting roles such as in "Everest", but became famous after landing which role?'},
#  {'answer': 'Knowing',
#   'question': 'What science fiction thriller starred Nicholas Cage and was directed by Alex Proyas?'},
#  {'answer': 'Jiah Khan',
#   'question': 'Which star of Nishabd appeared in three Hindi films from 2007 to 2010?'},
#  {'answer': 'David Ogden Stiers',
#   'question': 'Who is the American Actor who starred in Wife, Mother, Murderer?'},
#  {'answer': '24 May 1923',
#   'question': 'The ancestral home of George Henry Moore was burned down during a conflict that ended on what date?'},
#  {'answer': 'magazine',
#   'question': 'Moves and Heavy Metal, are which type of publication?'},
#  {'answer': '66',
#   'question': 'Terfenol-D is an alloy that contains a chemical element with an atomic number of what?'},
#  {'answer': 'India',
#   'question': 'The elder sister of David Bowes-Lyon married a prince who was the last Emperor of what country?'},
#  {'answer': 'Pythagorean theorem',
#   'question': 'Which geometrical theorem is a fundamental relation in Euclidean geometry involving the longest side of a right-angled triangle?'},
#  {'answer': '2004',
#   'question': 'In what year did the Chickasaw Nation open Win Star World Casino just 100 miles away from Chisholm Trail Casino?'},
#  {'answer': '22',
#   'question': 'The documentary film "In Beaver Valley" was produced by a man that won how many Oscars?'},
#  {'answer': 'no',
#   'question': 'Were Tom Meighan and Rose McDowall members of the same band?'},
#  {'answer': 'yes',
#   'question': 'Are Tennis and PC Gamer the same kind of publication?'},
#  {'answer': '1838',
#   'question': 'When was the Australian suburb founded in the district named after Thomas Elder founded on the banks of the Strut River?'},
#  {'answer': '1969',
#   'question': 'The UFC president who called Anderson Silva "the greatest mixed martial artist of all time" was born in this year?'},
#  {'answer': 'Mimus polyglottos',
#   'question': 'What is the species name of the animal in which the University of Tennessee at Chattanooga has as a mascot?'},
#  {'answer': 'BRP "Ang Pangulo"',
#   'question': 'What is the name of the presidnetial yacht acquired by the Philippine government in 1959 and has hosted many guests including ballerina Margot Fonteyn?'},
#  {'answer': 'Imperial Russia',
#   'question': 'Where was the writer of "Puttin\' On the Ritz" born?'},
#  {'answer': 'The Golden Ass',
#   'question': "What was St. Augustine's nickname for a 2nd Century AD story whose characters appeared in Greek art in the 4th century BC?"},
#  {'answer': 'Megumu Ishiguro',
#   'question': 'Who directed the series that stars Nicole Bouma as Blossom?'},
#  {'answer': 'Coney Island',
#   'question': "What is a peninsular residential neighborhood, beach, and leisure/entertainment destination, that holds an annual American hot dog competitive eating competition on Independence Day at Nathan's Famous Corporation's original?"},
#  {'answer': 'Andie MacDowell',
#   'question': 'Which actress was casted in both "Sex, Lies and Video Tapes" and "Michael" ?'},
#  {'answer': 'South Asia',
#   'question': 'Indra is a given name which occurs independently in Latvia, where it is feminine, and in which term used to represent the southern region of the Asian continent, which comprises the sub-Himalayan SAARC countries and, for some authorities, adjoining countries to the west and east?'},
#  {'answer': 'Paper Trail',
#   'question': ' "Crack a Bottle" broke the first week digital sales record with 418,000 downloads, topping the previous record held by a song that was featured on which album ?'},
#  {'answer': 'The Curiosity Company',
#   'question': 'Which company owned by Matt Groening features a logo with the letter "C" formed by a reflected surfboard?'},
#  {'answer': 'yes',
#   'question': 'Are both Qufu and Yongcheng cities in China ?'},
#  {'answer': 'John Whitney',
#   'question': 'Who founded an American family notable for their social prominence, wealth, business enterprises and philanthropy, who has a member by marriage who isan American poet, writer, racehorse owner/breeder, socialite, and philanthropist ?  '},
#  {'answer': 'Northamptonshire and Buckinghamshire border',
#   'question': 'Juan Carlos Sistos won the Silverston Grand Prix Circuit which straddles where?'},
#  {'answer': 'Brian Harold May',
#   'question': 'Kerry Ellis Sings the Great British Songbook was the first set of solo concerts by English stage actress and singer Kerry Ellis, it included an encore with which English musician, singer, songwriter and astrophysicist, best known as the lead guitarist of the rock band Queen?'},
#  {'answer': 'producer, director',
#   'question': 'What do Léonce Perret and Larry Cohen have in common in the film industry?'},
#  {'answer': '1982',
#   'question': 'Abyss is a steel roller coaster located in an amusement park that opened in which year ?'},
#  {'answer': 'Festus Claudius "Claude" McKay',
#   'question': 'If We Must Die is a poem by which Jamaican writer?'},
#  {'answer': 'Peter Paige and Bradley Bredeweg',
#   'question': 'Cierra Alexa Ramírez  is an American actress best known for her role in a television series created by who?'},
#  {'answer': 'Coronation of the Virgin',
#   'question': 'What mosaic inside the main church of Florence is attributed to Gaddo Gaddi?'},
#  {'answer': 'Belcore',
#   'question': 'Which character did Domenico Trimarchi portray in the Opera that first premiered on 12 May 1832?'},
#  {'answer': 'Camp Granada',
#   'question': 'What board game was released first, Diamond or Camp Granada?'},
#  {'answer': 'Earnie Shavers',
#   'question': 'Which fighter did both Ron Stander and James Tillis beat though their victories were more than 10 years apart ?'},
#  {'answer': 'Joseph Haydn',
#   'question': 'Ludwig Wenzel Lachnith was influenced by which Austrian "Father of the Symphony?"'},
#  {'answer': 'computers',
#   'question': 'What type of technology is  Pecom 32 and Apple IIc Plus'},
#  {'answer': 'Texas Christian University',
#   'question': 'Which university has a mascot that is a horned frog: Texas Christian University or Emory University?'},
#  {'answer': '15 June 1924',
#   'question': 'What was the birthday of the former President of Israel whose resignation resulted in the 2000 election?'},
#  {'answer': 'Analog Science Fiction and Fact',
#   'question': 'Which magazine was founded first, Analog Science Fiction and Fact or Star?'},
#  {'answer': 'Royal Purple',
#   'question': 'What is the official color of the college that Joe Holsinger attended?'},
#  {'answer': 'Dragon',
#   'question': 'An artist who illustrated some of the earliest editions of the "Dungeons & Dragons" role-playing game also  originally serialized a comic in which magazine?'},
#  {'answer': 'Black Nova Scotians',
# ...
#   'question': 'The star of "Lady in a Cage" was born in what year?'},
#  {'answer': 'United States',
#   'question': "he Loyola Greyhounds men's lacrosse team represents Loyola University Maryland, a Roman Catholic, Jesuit private liberal arts university located within the Archdiocese of Baltimore in the city of Baltimore, Maryland, in which country?"},
#  {'answer': 'Carol Reed',
#   'question': 'Sir Harry Donald Secombe appeared notably as Mr Buble in a 1968 British musical drama film directed by who?'},
#  {'answer': 'Kunal Nayyar',
#   'question': 'Which actor starred in Dr. Cabbie and "The Big Bang Theory"?'},
#  {'answer': 'John Guilbert Avildsen',
#   'question': 'Which director was born first, John G. Avildsen or Charles Martin Smith?'},
#  {'answer': 'magnesium',
#   'question': 'The Oxus cobra contains what kind of ions for their venom to be active? '},
#  {'answer': 'Zack Snyder',
#   'question': 'Who directed a superman movie in Plano, Illinois?'},
#  {'answer': 'February 23, 1979',
#   'question': 'When was the author of Losing Our Religion born?'},
#  {'answer': '1,324,108',
#   'question': 'DeSoto County is located in a metropolitan area that had how many inhabitants in 2010 ?'},
#  {'answer': '1537',
#   'question': 'Olivier Fillieule is a full-time Professor at a univeristy founded as a school of theology in what year?'},
#  {'answer': '1996',
#   'question': '"Hail Mary" is a single by American rapper Tupac Shakur, who died on September 13, of which year?'},
#  {'answer': 'the cypress family',
#   'question': 'What family of trees is the tree that grows in Alerce Costero National Park?'},
#  {'answer': 'Ridley Scott',
#   'question': 'Who directed the Academy Award winning film Giorgio Cantarini appeared in in 2000?'},
#  {'answer': 'Paul Simon',
#   'question': 'Q: Who as collaborated musically with both Leo Abrahams and Art Garfunkel?'},
#  {'answer': 'Juventus',
#   'question': 'Who was the winner of the European Cup the year that 39 people were killed?'},
#  {'answer': 'William Franklin',
#   'question': 'Who is The Royal Governor and American-born attorney in the 1700s?'},
#  {'answer': 'drink',
#   'question': 'Jazz and Dr Pepper, are a type of what item?'},
#  {'answer': 'San Francisco, California',
#   'question': 'Lenny Von Dohlen was an architect in the 1984 movie set in what location?'},
#  {'answer': 'United Kingdom',
#   'question': 'What country was Daniel Awde born in?'},
#  {'answer': 'Space',
#   'question': 'What environment did both Dirk Frimout and Klaus-Dietrich Flade work in?'},
#  {'answer': '1932',
#   'question': "In what year was George Pataki's opponent in the 1994 governor race born?"},
#  {'answer': 'London',
#   'question': 'rom March 2013 to October 2014, Omid Kordestani was the Non-executive Director at a company with headquarters in which city ?'},
#  {'answer': 'Hrithik Roshan',
#   'question': 'Krazzy 4 is a 2008 Bollywood comedy film with music by a Hindi cinema music composer who is the uncle of what actor?'},
#  {'answer': 'The St. Lawrence and Atlantic Railroad',
#   'question': 'Locomotives kept grand trunk lettering for service in the U.s on railroads such as this known as st-laurent et atlantique quebec? '},
#  {'answer': 'satirical erotic romantic comedy',
#   'question': 'What movie genre did Emmanuelle Vaugier play a supporting role in?'},
#  {'answer': "New Zealand Woman's Weekly",
#   'question': "Which Magazine publishes more frequently, Lucire or New Zealand Woman's Weekly?"},
#  {'answer': 'yes',
#   'question': 'E. Howard Hunt and Miguel Delibes, were in the writing industry?'},
#  {'answer': 'Sweet Crude',
#   'question': "What is a documentary film by Sandy Cioffi about Nigeria's oil-rich Niger Delta, Trembling Before G-d or Sweet Crude ?"},
#  {'answer': '13 May [O.S. 1 May] 1850',
#   'question': 'When was the Russian librettist whose work was used in the opera Dubrovsky born?'},
#  {'answer': 'Robert Erskine Childers DSC',
#   'question': 'Which writer was from England, Henry Roth or Robert Erskine Childers?'},
#  {'answer': 'Fox',
#   'question': 'What TV network did the Simpsons and Them Robot air?'},
#  {'answer': 'Greek Fire',
#   'question': 'In between TV on the Radio and Greek Fire,which one was formed in 2008?'},
#  {'answer': 'George W. Bush',
#   'question': 'Which former president of the United States, married to Laura Lane Welch Bush, was the 46th Governor of Texas from 1995 to 2000?'},
#  {'answer': 'Alexander Macris',
#   'question': 'Benjamin Richard "Yahtzee" Croshaw is best known for his acerbic video game review series for an online magazine published by who?'},
#  {'answer': 'Stefanie Maria "Steffi" Graf',
#   'question': 'Out of Chris Evert and Steffi Graf, who won the most grandslam singles titles?'},
#  {'answer': '18.7 miles',
#   'question': 'How far is the village located from Central London between which and Potters Barthe viillage Ridge is situated?'},
#  {'answer': 'Ford Fusion',
#   'question': 'What vehicle, introduced for model year 2006, does Patrick Carpentier currently drive in the NASCAR Sprint Cup Series?'},
#  {'answer': 'Elizabeth Tower',
#   'question': 'What is the official name of the tower, previously known as Clock Tower, next to which a proposed Thames Airport was to be built in the 1930s?'},
#  {'answer': 'Central, Hong Kong',
#   'question': "The traditional cuisine Mak's Noodle is located where?"},
#  {'answer': 'Soha Ali Khan',
#   'question': 'Saheb Biwi Aur Gangster Returns, is a 2013 Indian Hindi romantic thriller drama, starring what new cast member born October 1978?'},
#  {'answer': '1851',
#   'question': 'Antoni Norbert Patek was the one of the creators of a watch company founded in what year?'},
#  {'answer': 'Paris',
#   'question': "To where did a co-founder of the Women's Social and Political Union flee, leaving Rachel Barrett as the joint organiser?"},
#  {'answer': 'David Leveaux',
#   'question': "The Kaiser's Last Kiss led to a film that was directed by whom?"},
#  {'answer': 'The Snowball Derby',
#   'question': 'Which stock car automobile race held in December did Dave Mader III win?'},
#  {'answer': 'yellow and black',
#   'question': 'What was the color of the twin-rotor Wankel rotary engine car driven by Peter McLeod?'},
#  {'answer': 'Charley Chase',
#   'question': 'Which American screenwriter is best known for his work on short film comedies, Charley Chase or Marc Lawrence?'},
#  {'answer': '1874',
#   'question': 'In which year was this public research university in which Brock Marion played college football founded?'},
#  {'answer': 'no',
#   'question': 'Was Nabil Ayouch initially a playwright like John McKay?'},
#  {'answer': '15',
#   'question': 'How many animals does the wall running between the West Gate Lodge and Cardiff Castle depict?'},
#  {'answer': '1959',
#   'question': "What year was the head coach for the Kentucky Wildcats men's basketball team born?"},
#  {'answer': 'Wagner Maniçoba',
#   'question': 'The the protagonist in the first fictional film directed by José Padilha was played by who?'},
#  {'answer': 'National University of Singapore',
#   'question': 'Which institution in Singapore that was founded in 1905 appointed this researcher who was the James McGill Professor in the Department of East Asian Studies of McGill University?'},
#  {'answer': 'September 25, 1866',
#   'question': "What was the birthday of the man who Don Melnick's position is named after?"},
#  {'answer': 'George McGovern',
#   'question': 'Who was the Democratic Party presidential nominee that lost to Richard Nixon in the 1972 presidential election?'},
#  {'answer': 'Liverpool Bay',
#   'question': "Which bay in the Irish Sea is located Wales's first offshore wind farm?"},
#  {'answer': 'March 12, 1946',
#   'question': 'When was the voice actor who played Laddie in The Canine Mutiny born?'},
#  {'answer': 'band',
#   'question': 'What kind of group does Trym Torson and Emperor have in common?'},
#  {'answer': 'Kevin Colbert',
#   'question': 'Who was the manager above tenth Pittsburgh Steeler head coach Mike Tomlin?'},
#  {'answer': 'Austin, Texas',
#   'question': 'Jagmo, born Nels Jacobson, is a US artist and poster art historian born in Chicago in 1949, he has designed posters for live-music venues such as Jimmie Dale Gilmore, an American country singer, songwriter, actor, recording artist and producer, currently living where?'},
#  {'answer': 'John Burdon Sanderson Haldane',
#   'question': 'Leading evolutionary game theorist John Maynard Smith was taught at university by which British-born Indian scientist?'},
#  {'answer': 'Lewis Gilbert',
#   'question': 'Which film director was born earlier, Lewis Gilbert or Kiyoshi Kurosawa?'},
#  {'answer': 'singer',
#   'question': 'What profession did both Juliette Lewis and Guy Chadwick share?'},
#  {'answer': 'the 3,000-strikeout club',
#   'question': 'What club does Curt Schilling hold the highest strikeout-to-walk ratio of any of its members?'},
#  {'answer': 'Ronald Wilson Reagan',
#   'question': 'Frank Hodsoll was appointed to the chairmanship of the NEA by which 40th President?'},
#  {'answer': 'The Ultimate Fighter 1',
#   'question': 'What martial arts television show featured Stephan Bonnar as runner up in season one?'},
#  {'answer': 'Luka Modrić',
#   'question': 'Which player produced from the GNK Dinamo Zagreb Academy now plays for Real Madrid ?'},
#  {'answer': '1 August',
#   'question': "When did Bayern Munich win their first competitive game under Barcelona's former manager?"},
#  {'answer': 'yes', 'question': 'Are Euptelea and Muehlenbeckia both genuses?'},
#  {'answer': 'Daniel DeWayne Severn',
#   'question': 'Pedro Rizzo had a victory over what American mixed martial artist know for his success in the early years of UFC?'},
#  {'answer': 'World War II',
#   'question': 'In which war did Operation Undertone, a large assault by the US and French Armies and the Battle of Mindanao, fought by the US and allied Filipino guerrillas take place?'},
#  {'answer': 'Hardenbergia',
#   'question': 'Between Loropetalum and Hardenbergia, which originates from Australia?'},
#  {'answer': 'chloroprene',
#   'question': 'Boots that rise to the knee and were originally made of leather, can be made of a synthetic rubber that exhibits good chemical stability, and is produced by the polymerization of what? '},
#  {'answer': 'November 20, 1942',
#   'question': 'When was the  American singer-songwriter born who recorded “Spirit In The Sky”?'},
#  {'answer': 'Raai Laxmi',
#   'question': 'Phulwa Khamkar choreographed a Hindi thriller film that features who in her debut in Hindi cinema?'},
#  {'answer': 'yes',
#   'question': 'Are Staten Island Catapult and This Is Elvis both documentaries?'},
#  {'answer': 'Buffalo Soldier',
#   'question': 'Who were originally members of the 10th Cavalry Regiment of the United States Army, and included William H. Thompkins, a recipient of the Medal of Honor, for his actions in the Spanish-American War?'},
#  {'answer': 'Arlene Phillips',
#   'question': 'Fanfare Records was a British record label that was founded by Lain Burton which was the manager of who?'},
#  {'answer': 'Chester Opera House',
#   'question': 'Which Opera house has the creator of Popeye worked at from the age of twelve?'},
#  {'answer': '"Strictly Dance Fever"',
#   'question': 'What t.v. program promoted a modern afro-Cuban partner dance that is a fusion of rhythm developed from the danzón-mambo, and hip hop?'},
#  {'answer': 'fourteen',
#   'question': 'How many movements are in the musical suite that includes "Le cygne"?'},
#  {'answer': 'plants',
#   'question': 'Lantana and Phlomis, are a species of which entity?'},
#  {'answer': 'Berlin International Film Festival',
#   'question': ' Valkarkay is a bay was the primary location used in a film that was critically acclaimed and nominated for the Golden Bear at the 60th what?'},
#  {'answer': 'Wagnerian',
#   'question': 'Camilla Pasini (6 November 1875 – 29 November 1935) was an Italian operatic soprano, her sister, Lina Pasini-Vitale was a well known what soprano, a dramatic soprano is a type of operatic soprano with a powerful, rich, emotive voice that can sing over, or cut through, a full orchestra?'},
#  {'answer': '"The Voice"',
#   'question': '10 Years of Hits – Newly Recorded is a compilation album by a country music artist known by what nickname?'},
#  {'answer': 'three',
#   'question': 'How many years in prison did the Norfolk farmer defended by Anthony Scrivener serve?'},
#  {'answer': 'University of Essex',
#   'question': 'Where did the Labour politician with an employee who later became editor of a left-wing website work as a lecturer before entering politics?'},
#  {'answer': 'Marion, Indiana',
#   'question': 'Where is the headquarters of the place that the Christian Educational Consortium meets?'},
#  {'answer': 'Houston',
#   'question': "What was the middle name of the sitting Governor of Louisiana when Louisiana Governor's Mansion was built?"},
#  {'answer': 'World Without Love',
#   'question': 'Which Paul McCartney song did Del Davis sing on "Mellow Dubmarine."'},
#  {'answer': 'Zürich',
#   'question': 'In 1988 Allmänna Svenska Elektriska Aktiebolaget merged with a swiss company headquartered in what city?'},
#  {'answer': '48,818',
#   'question': 'What was the population as of the 2010 census of the county in which Grindstone Mountain is located?'},
#  {'answer': 'Whose Line is it Anyway',
#   'question': 'The 5th Wheel was initially hosted by the now-host of what comedy show?'},
#  {'answer': '1980s',
#   'question': 'In what decade are the works of Neil Tennant and Kim Wilson known for?'},
#  {'answer': 'Iron Wolf',
#   'question': 'Which mythical character from medieval legend because popular during the era of Romantic nationalism and has a core unit of the Lithuanian Army name inspired by him?'},
#  {'answer': 'Alice Malsenior Walker',
#   'question': 'Did Andrei Platonov or Alice Walker win more Pulitzer prizes?'},
#  {'answer': 'Riff Raff',
#   'question': 'Which rapper from Houston, Texas was produced by Axident?'},
#  {'answer': 'Jean-Loup Jacques Marie Chrétien',
#   'question': 'Who is older, Claudie Haigneré or Jean-Loup Chrétien?'},
#  {'answer': 'London',
#   'question': 'In which city is the main management office of the company that owns J. Walter Thompson located?'},
#  {'answer': 'no',
#   'question': 'Were Harry Beaumont and Lucio Fulci directors of the same nationality?'},
#  {'answer': 'Jay Russell',
#   'question': ' Kevin Daniels had a part in the 2004 American drama directed by whom?'},
#  {'answer': 'Mitchell Parish',
#   'question': 'Who added lyrics to a song that was composed by a man described by John Williams as "one of the great American masters of light orchestral music"?'},
#  {'answer': 'the whitest sand in the world',
#   'question': 'Lake Wollumboola lies to the north of a bay that is said to possess what?'},
#  {'answer': 'American',
#   'question': 'Micky Ward and The Ring magazine Fight of the Year are from which country?'},
#  {'answer': 'Caesars Entertainment Corporation',
#   'question': ' The AXIS  is a mid-sized auditorium located at a hotel and casino owned by what corporation?'},
#  {'answer': 'Mosè in Egitto',
#   'question': 'Between the two operas, Mosè in Egitto and Lucrezia Borgia, which one has more acts?'},
#  {'answer': '339',
#   'question': 'Ian MacDougall served as Commissioner of an agency of the Government of New South Wales that has how many fire stations ?'},
#  {'answer': 'no',
#   'question': 'Are John Bilezikjian and Richard Donchian from the same state?'},
#  {'answer': 'Mario Gianluigi Puzo',
#   'question': 'Which author was the last to die, Mario Puzo or Edith Hamilton?'},
#  {'answer': 'yes',
#   'question': 'Are Stefan Edberg and Patty Fendick both tennis players?'},
#  {'answer': 'Thomas Hodge "Tom" Allen',
#   'question': 'What former member of the United States House of Representatives took over as president and CEO of The Association of American Publishers?'},
#  {'answer': 'Robert N. Bradbury',
#   'question': 'Which director was best known for westerns, Robert N. Bradbury or Rob Schneider?'},
#  {'answer': 'California',
#   'question': 'In what state did this band form that is an American metalcore band, founded in mid-2009, and whose lead vocalist was Jerry Roush?'},
#  ...]

# %%
import ijson

def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(value)
    return questions

qa_file_path = '/home/eternal/qa_train.json'
questions = extract_questions(qa_file_path)
print(questions[:10])  # 추출된 질문 일부 출력
# Out:
# ['In what year the the venue that Marcia White is president of open?', 'What country is home to the sports club loaning Bruno Paulista to Vasco da Gama?', '"Southern Air" featured Ray Stevens, Minnie Pearl and what other Southern comedian?', 'The Treaty of Prairie du Chien may refer to any of several treaties made between the United States and representatives from the native american people who called themselves what?', 'What profession do Thomas Merton and Michael Moorcock have in common?', 'Who was the first person to describe Relational Quantum mechanics and has worked in Italy, the United States, and France?', 'Where is the Silver Dollar city theme park with the Grand exposition  steel roller coaster located?', 'Finna Get Loose is a song by Puff Daddy and what American rapper who is also a record and film producer?', 'What town is Hore Abbey located near?', 'In what year was the actress who was starred in "The Telling" with Holly Madison born?']
# Extracted 105501507 relevant sentences.

# %%
import ijson

def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(value)
    return questions

qa_file_path = '/home/eternal/qa_train.json'
questions = extract_questions(qa_file_path)
print(questions[:10])  # 추출된 질문 일부 출력


def extract_relevant_sentences(questions, wiki_file_path, output_file_path):
    relevant_sentences = []
    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        for line in wiki_file:
            for question in questions:
                if any(word in line for word in question.split()):
                    relevant_sentences.append(line)
                    break

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        for sentence in relevant_sentences:
            output_file.write(sentence)
    
    return relevant_sentences

wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path='/home/eternal/processed_wikipedia.txt/relevant_sentences.txt'
relevant_sentences = extract_relevant_sentences(questions, wiki_file_path, output_file_path)
print(f"Extracted {len(relevant_sentences)} relevant sentences.")
# Out:
# Extracted 105501507 relevant sentences.

# %%
import ijson
import re
from difflib import SequenceMatcher
import nltk
from nltk.corpus import words
from spellchecker import SpellChecker
import sys
import time
from multiprocessing import Pool, cpu_count

# Ensure nltk word list is downloaded
nltk.download('words')

# 파일 경로 설정
qa_file_path = '/home/eternal/this/qa_train.json'
wiki_file_path = '/home/eternal/this/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path = '/home/eternal/this/processed_wikipedia_filtered.txt'

'''
# 기존 파일 삭제하고 새 파일로 대체
import os
print("Replacing original file with the filtered file...")
os.remove(wiki_file_path)
os.rename(output_file_path, wiki_file_path)
print("Replacement complete.")
'''
def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(value)
    return questions

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    return text

def correct_spelling(text):
    spell = SpellChecker()
    corrected_text = []
    for word in text.split():
        corrected_word = spell.correction(word)
        if corrected_word is None:
            corrected_word = word
        corrected_text.append(corrected_word)
    return ' '.join(corrected_text)

def is_relevant_sentence(question, sentence, threshold=0.6):
    question = correct_spelling(preprocess_text(question))
    sentence = correct_spelling(preprocess_text(sentence))
    similarity = SequenceMatcher(None, question, sentence).ratio()
    return similarity > threshold

def process_chunk(args):
    questions, chunk, threshold = args
    relevant_sentences = set()
    for line in chunk:
        for question in questions:
            if is_relevant_sentence(question, line, threshold):
                relevant_sentences.add(line.strip())
                break
    return relevant_sentences

def extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path, chunk_size=1000000, num_workers=4):
    relevant_sentences = set()
    total_lines = sum(1 for _ in open(wiki_file_path, 'r', encoding='utf-8'))

    start_time = time.time()
    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        pool = Pool(num_workers)
        chunk = []
        for i, line in enumerate(wiki_file):
            chunk.append(line)
            if (i + 1) % chunk_size == 0:
                try:
                    elapsed_time = time.time() - start_time
                    lines_processed = i + 1
                    remaining_lines = total_lines - lines_processed
                    estimated_total_time = (elapsed_time / lines_processed) * total_lines
                    estimated_remaining_time = estimated_total_time - elapsed_time
                    print(f"Processing line {lines_processed}/{total_lines}")
                    print(f"Elapsed time: {elapsed_time:.2f} seconds")
                    print(f"Estimated remaining time: {estimated_remaining_time / 3600:.2f} hours")
                    sys.stdout.flush()
                    # Use starmap to pass multiple arguments to process_chunk
                    results = pool.starmap(process_chunk, [(questions, chunk, 0.6)])
                    for result in results:
                        relevant_sentences.update(result)
                    chunk = []
                except Exception as e:
                    print(f"Error processing chunk at line {i+1}: {e}")
                    sys.stdout.flush()
        
        # Process remaining lines
        if chunk:
            try:
                results = pool.starmap(process_chunk, [(questions, chunk, 0.6)])
                for result in results:
                    relevant_sentences.update(result)
            except Exception as e:
                print(f"Error processing final chunk: {e}")
                sys.stdout.flush()

    pool.close()
    pool.join()

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        for sentence in relevant_sentences:
            output_file.write(sentence + '\n')

    return relevant_sentences


# 질문 추출
print("Extracting questions...")
questions = extract_questions(qa_file_path)
print(f"Extracted {len(questions)} questions.")
print(questions[:10])  # 추출된 질문 일부 출력

# 관련 문장 추출 및 저장
print("Extracting relevant sentences...")
relevant_sentences = extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path)
print(f"Extracted {len(relevant_sentences)} relevant sentences.")
# Out:
# [nltk_data] Downloading package words to /home/eternal/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Extracting questions...
# Extracted 88066 questions.
# ['In what year the the venue that Marcia White is president of open?', 'What country is home to the sports club loaning Bruno Paulista to Vasco da Gama?', '"Southern Air" featured Ray Stevens, Minnie Pearl and what other Southern comedian?', 'The Treaty of Prairie du Chien may refer to any of several treaties made between the United States and representatives from the native american people who called themselves what?', 'What profession do Thomas Merton and Michael Moorcock have in common?', 'Who was the first person to describe Relational Quantum mechanics and has worked in Italy, the United States, and France?', 'Where is the Silver Dollar city theme park with the Grand exposition  steel roller coaster located?', 'Finna Get Loose is a song by Puff Daddy and what American rapper who is also a record and film producer?', 'What town is Hore Abbey located near?', 'In what year was the actress who was starred in "The Telling" with Holly Madison born?']
# Extracting relevant sentences...
# Processing line 1000000/105502474
# Elapsed time: 0.32 seconds
# Estimated remaining time: 0.01 hours
# Error processing chunk at line 1000000: process_chunk() takes 1 positional argument but 3 were given
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-1:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 125
#     123 # 관련 문장 추출 및 저장
#     124 print("Extracting relevant sentences...")
# --> 125 relevant_sentences = extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path)
#     126 print(f"Extracted {len(relevant_sentences)} relevant sentences.")
#
# Cell In[9], line 76, in extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path, chunk_size, num_workers)
#      74 chunk = []
#      75 for i, line in enumerate(wiki_file):
# ---> 76     chunk.append(line)
#      77     if (i + 1) % chunk_size == 0:
#      78         try:
#
# KeyboardInterrupt:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
#!pip install sentence-transformers
#!pip install spellchecker
#!pip install language-tool-python

import json
import re
from sentence_transformers import SentenceTransformer, util
from spellchecker import SpellChecker
import language_tool_python
from tqdm import tqdm

# SentenceTransformer 모델 로드
model = SentenceTransformer('all-MiniLM-L6-v2')

# 언어 도구와 맞춤법 검사기 설정
spell = SpellChecker()
tool = language_tool_python.LanguageTool('en-US')

# 텍스트 정제 함수
def clean_text(text):
    text = text.strip()
    text = re.sub(r'\s+', ' ', text)  # 여러 개의 공백을 단일 공백으로 대체
    text = re.sub(r'[^\w\s.,!?]', '', text)  # 특수 문자 제거
    return text

# 오탈자 수정 함수
def correct_spelling(text):
    corrected_text = []
    for word in text.split():
        corrected_word = spell.correction(word)
        if corrected_word is None:
            corrected_text.append(word)
        else:
            corrected_text.append(corrected_word)
    return ' '.join(corrected_text)

# 문법 검사 및 수정 함수
def correct_grammar(text):
    matches = tool.check(text)
    corrected_text = language_tool_python.utils.correct(text, matches)
    return corrected_text

# 전체 텍스트 정제 함수
def preprocess_text(text):
    text = clean_text(text)
    text = correct_spelling(text)
    text = correct_grammar(text)
    return text

# 데이터 로드 및 유사도 기반 전처리 (데이터의 일부만 처리)
def load_and_clean_data(file_path, top_k=5, limit=None):
    with open(file_path, "r") as file:
        data = json.load(file)
    
    if limit:
        data = data[:limit]
    
    clean_data = []
    for item in tqdm(data, desc="Processing data"):
        question = clean_text(item["question"])
        question_embedding = embed_texts([question])
        
        answers = [clean_text(answer) for answer in item.get("answers", [])]
        if not answers:
            continue
        
        answer_embeddings = embed_texts(answers)
        similarities = calculate_similarity(question_embedding, answer_embeddings)
        
        top_indices = similarities.argsort(descending=True).tolist()[0][:top_k]
        for idx in top_indices:
            clean_item = {
                "question": question,
                "answer": preprocess_text(answers[idx])
            }
            clean_data.append(clean_item)
    
    return clean_data

# 데이터의 일부만 로드
#train_data = load_and_clean_data("/home/eternal/this/qa_train.json", limit=1000)
#test_data = load_and_clean_data("/home/eternal/this/qa_test.json", limit=1000)

#with open("/home/eternal/this/processed_wikipedia.txt", "r") as file:
#    knowledge_base = [preprocess_text(line) for line in tqdm(file, desc="Processing knowledge base", total=1000)]


train_data = load_and_clean_data("/home/eternal/this/qa_train.json", limit=1000)
test_data = load_and_clean_data("/home/eternal/this/qa_test.json", limit=1000)

with open(knowledge_base_file, "r") as file:
    knowledge_base = [preprocess_text(line) for line in tqdm(file, desc="Processing knowledge base", total=total_lines)]
# Out:
# Processing data: 100%|█████████████████████| 1000/1000 [00:01<00:00, 576.47it/s]
# Processing data: 100%|█████████████████████| 1000/1000 [00:01<00:00, 588.78it/s]
# Processing knowledge base:  23%|██▉          | 227/1000 [02:50<06:08,  2.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 92
#      89 test_data = load_and_clean_data("/home/eternal/this/qa_test.json", limit=1000)
#      91 with open("/home/eternal/this/processed_wikipedia.txt/processed_wikipedia.txt", "r") as file:
# ---> 92     knowledge_base = [preprocess_text(line) for line in tqdm(file, desc="Processing knowledge base", total=1000)]
#
# Cell In[16], line 92, in <listcomp>(.0)
#      89 test_data = load_and_clean_data("/home/eternal/this/qa_test.json", limit=1000)
#      91 with open("/home/eternal/this/processed_wikipedia.txt/processed_wikipedia.txt", "r") as file:
# ---> 92     knowledge_base = [preprocess_text(line) for line in tqdm(file, desc="Processing knowledge base", total=1000)]
#
# Cell In[16], line 46, in preprocess_text(text)
#      44 def preprocess_text(text):
#      45     text = clean_text(text)
# ---> 46     text = correct_spelling(text)
#      47     text = correct_grammar(text)
#      48     return text
#
# Cell In[16], line 30, in correct_spelling(text)
#      28 corrected_text = []
#      29 for word in text.split():
# ---> 30     corrected_word = spell.correction(word)
#      31     if corrected_word is None:
#      32         corrected_text.append(word)
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:158, in SpellChecker.correction(self, word)
#     151 """The most probable correct spelling for the word
#     152
#     153 Args:
#     154     word (str): The word to correct
#     155 Returns:
#     156     str: The most likely candidate or None if no correction is present"""
#     157 word = ensure_unicode(word)
# --> 158 candidates = self.candidates(word)
#     159 if not candidates:
#     160     return None
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:185, in SpellChecker.candidates(self, word)
#     183 # if still not found, use the edit distance 1 to calc edit distance 2
#     184 if self._distance == 2:
# --> 185     tmp = self.known(list(self.__edit_distance_alt(res)))
#     186     if tmp:
#     187         return tmp
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:252, in SpellChecker.__edit_distance_alt(self, words)
#     250 tmp_words = [ensure_unicode(w) for w in words]
#     251 tmp = [w if self._case_sensitive else w.lower() for w in tmp_words if self._check_if_should_check(w)]
# --> 252 return [e2 for e1 in tmp for e2 in self.known(self.edit_distance_1(e1))]
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:252, in <listcomp>(.0)
#     250 tmp_words = [ensure_unicode(w) for w in words]
#     251 tmp = [w if self._case_sensitive else w.lower() for w in tmp_words if self._check_if_should_check(w)]
# --> 252 return [e2 for e1 in tmp for e2 in self.known(self.edit_distance_1(e1))]
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:199, in SpellChecker.known(self, words)
#     197 tmp_words = [ensure_unicode(w) for w in words]
#     198 tmp = [w if self._case_sensitive else w.lower() for w in tmp_words]
# --> 199 return {w for w in tmp if w in self._word_frequency.dictionary and self._check_if_should_check(w)}
#
# File ~/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py:199, in <setcomp>(.0)
#     197 tmp_words = [ensure_unicode(w) for w in words]
#     198 tmp = [w if self._case_sensitive else w.lower() for w in tmp_words]
# --> 199 return {w for w in tmp if w in self._word_frequency.dictionary and self._check_if_should_check(w)}
#
# KeyboardInterrupt:

# %%
knowledge_base

# %%
import language_tool_python

tool = language_tool_python.LanguageTool('en-US')

def correct_grammar(text):
    matches = tool.check(text)
    corrected_text = language_tool_python.utils.correct(text, matches)
    return corrected_text

def postprocess_text(text):
    text = clean_text(text)
    text = correct_grammar(text)
    return text

# %%
# 테스트 질문에 대한 답변 생성 및 포스트 프로세싱 적용
results = []

for question in test_questions:
    inputs = tokenizer(question, return_tensors="pt")
    generated_answers = model.generate(input_ids=inputs["input_ids"], attention_mask=inputs["attention_mask"])
    decoded_answers = tokenizer.batch_decode(generated_answers, skip_special_tokens=True)
    postprocessed_answer = postprocess_text(decoded_answers[0])
    results.append({"question": question, "answer": postprocessed_answer})

# 결과 저장
with open("predictions.json", "w") as file:
    json.dump(results, file, indent=4)

# %%
#작동안되는 무한루프

import re
import time
import multiprocessing
import ijson
import os
from datetime import datetime

def preprocess_sentence(sentence):
    sentence = sentence.lower()
    sentence = re.sub(r'[^\w\s]', '', sentence)
    sentence = re.sub(r'\s+', ' ', sentence).strip()
    return sentence

def process_lines(lines, questions):
    processed_lines = []
    for line in lines:
        original_line = line.strip()
        if any(word in original_line for question in questions for word in question.split()):
            processed_line = preprocess_sentence(original_line)
            processed_lines.append(processed_line + '\n')
        else:
            processed_lines.append(original_line + '\n')
    return processed_lines

def worker(wiki_file_path, questions, start, end, output_queue):
    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        wiki_file.seek(start)
        lines = wiki_file.read(end - start).splitlines()
        processed_lines = process_lines(lines, questions)
        output_queue.put(processed_lines)

def extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path, num_workers=4):
    start_time = datetime.now()
    print(f"Processing started at: {start_time}")

    file_size = os.path.getsize(wiki_file_path)
    chunk_size = file_size // num_workers

    output_queue = multiprocessing.Queue()
    processes = []
    for i in range(num_workers):
        start = i * chunk_size
        end = file_size if i == num_workers - 1 else (i + 1) * chunk_size
        p = multiprocessing.Process(target=worker, args=(wiki_file_path, questions, start, end, output_queue))
        processes.append(p)
        p.start()

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        for _ in range(num_workers):
            processed_lines = output_queue.get()
            output_file.writelines(processed_lines)

    for p in processes:
        p.join()

    end_time = datetime.now()
    elapsed_time = (end_time - start_time).total_seconds()
    print(f"Processing completed at: {end_time}")
    print(f"Total processing time: {elapsed_time:.2f} seconds")

def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(value)
    return questions

qa_file_path = '/home/eternal/qa_train.json'
questions = extract_questions(qa_file_path)

wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_cleaned.txt'
extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path)
# Out:
# Processing started at: 2024-06-09 16:06:49.719791
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 75
#      73 wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
#      74 output_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_cleaned.txt'
# ---> 75 extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path)
#
# Cell In[8], line 50, in extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path, num_workers)
#      48 with open(output_file_path, 'w', encoding='utf-8') as output_file:
#      49     for _ in range(num_workers):
# ---> 50         processed_lines = output_queue.get()
#      51         output_file.writelines(processed_lines)
#      53 for p in processes:
#
# File /usr/lib/python3.10/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /usr/lib/python3.10/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     377 remaining = size
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#     381     if n == 0:
#
# KeyboardInterrupt:

# %%
#시간 많이 걸림

import re
import time
import multiprocessing
import ijson
import os
from datetime import datetime

def preprocess_sentence(sentence):
    sentence = sentence.lower()
    sentence = re.sub(r'[^\w\s]', '', sentence)
    sentence = re.sub(r'\s+', ' ', sentence).strip()
    return sentence

def process_lines(lines, questions):
    processed_lines = []
    for line in lines:
        original_line = line.strip()
        if any(word in original_line for question in questions for word in question.split()):
            processed_line = preprocess_sentence(original_line)
            processed_lines.append(processed_line + '\n')
        else:
            processed_lines.append(original_line + '\n')
    return processed_lines

def worker(wiki_file_path, questions, start, end, output_queue):
    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        wiki_file.seek(start)
        lines = wiki_file.read(end - start).splitlines()
        processed_lines = process_lines(lines, questions)
        output_queue.put(processed_lines)
    output_queue.put("DONE")

def extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path, num_workers=4):
    start_time = datetime.now()
    print(f"Processing started at: {start_time}")

    file_size = os.path.getsize(wiki_file_path)
    chunk_size = file_size // num_workers

    output_queue = multiprocessing.Queue()
    processes = []
    for i in range(num_workers):
        start = i * chunk_size
        end = file_size if i == num_workers - 1 else (i + 1) * chunk_size
        p = multiprocessing.Process(target=worker, args=(wiki_file_path, questions, start, end, output_queue))
        processes.append(p)
        p.start()

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        completed_processes = 0
        while completed_processes < num_workers:
            processed_lines = output_queue.get()
            if processed_lines == "DONE":
                completed_processes += 1
            else:
                output_file.writelines(processed_lines)

    for p in processes:
        p.join()

    end_time = datetime.now()
    elapsed_time = (end_time - start_time).total_seconds()
    print(f"Processing completed at: {end_time}")
    print(f"Total processing time: {elapsed_time:.2f} seconds")

def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(value)
    return questions



qa_file_path = '/home/eternal/qa_train.json'
questions = extract_questions(qa_file_path)

wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_cleaned.txt'
extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path)
# Out:
# Processing started at: 2024-06-09 16:34:42.950179
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 82
#      80 wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
#      81 output_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_cleaned.txt'
# ---> 82 extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path)
#
# Cell In[9], line 52, in extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path, num_workers)
#      50 completed_processes = 0
#      51 while completed_processes < num_workers:
# ---> 52     processed_lines = output_queue.get()
#      53     if processed_lines == "DONE":
#      54         completed_processes += 1
#
# File /usr/lib/python3.10/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /usr/lib/python3.10/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     377 remaining = size
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#     381     if n == 0:
#
# KeyboardInterrupt:

# %%
#컴퓨터 데미지 입힌 코드

import ijson
import re
import os
import time
import multiprocessing
from rank_bm25 import BM25Okapi
from datetime import datetime

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)

    return text

def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(preprocess_text(value))
    return questions

def bm25_worker(wiki_lines, questions, worker_id, output_queue):
    try:
        tokenized_corpus = [preprocess_text(line).split() for line in wiki_lines]
        bm25 = BM25Okapi(tokenized_corpus)
        relevant_sentences = []

        for question in questions:
            tokenized_question = question.split()
            top_n = bm25.get_top_n(tokenized_question, wiki_lines, n=5)  # 상위 5개 문장 선택 (조정 가능)
            relevant_sentences.extend(top_n)

        output_queue.put((worker_id, relevant_sentences))
        output_queue.put(("DONE", worker_id))
    except Exception as e:
        output_queue.put((worker_id, f"ERROR: {e}"))

def extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path, num_workers=4):
    start_time = datetime.now()
    print(f"Processing started at: {start_time}")

    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        wiki_lines = wiki_file.readlines()

    chunk_size = len(wiki_lines) // num_workers
    output_queue = multiprocessing.Queue()
    processes = []

    for i in range(num_workers):
        start = i * chunk_size
        end = len(wiki_lines) if i == num_workers - 1 else (i + 1) * chunk_size
        p = multiprocessing.Process(target=bm25_worker, args=(wiki_lines[start:end], questions, i, output_queue))
        processes.append(p)
        p.start()

    processed_count = 0
    total_lines = len(wiki_lines)

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        completed_processes = 0
        while completed_processes < num_workers:
            result = output_queue.get()
            if result[0] == "DONE":
                worker_id = result[1]
                completed_processes += 1
                print(f"Worker {worker_id} completed. Total completed processes: {completed_processes}/{num_workers}")
            elif result[0] == "ERROR":
                worker_id = result[1]
                error_message = result[1]
                print(f"Worker {worker_id} encountered an error: {error_message}")
            else:
                worker_id, processed_lines = result
                output_file.writelines(processed_lines)
                processed_count += len(processed_lines)
                print(f"Worker {worker_id} processed {len(processed_lines)} lines. Total processed: {processed_count}/{total_lines}")

    for p in processes:
        p.join()

    end_time = datetime.now()
    elapsed_time = (end_time - start_time).total_seconds()
    print(f"Processing completed at: {end_time}")
    print(f"Total processing time: {elapsed_time:.2f} seconds")

qa_file_path = '/home/eternal/qa_train.json'
questions = extract_questions(qa_file_path)
print(questions[:10])  # 추출된 질문 일부 출력

wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path = '/home/eternal/processed_wikipedia.txt/relevant_sentences1.txt'
extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path)
print(f"Extracted relevant sentences saved to {output_file_path}.")
# Out:
# ['in what year the the venue that marcia white is president of open', 'what country is home to the sports club loaning bruno paulista to vasco da gama', 'southern air featured ray stevens minnie pearl and what other southern comedian', 'the treaty of prairie du chien may refer to any of several treaties made between the united states and representatives from the native american people who called themselves what', 'what profession do thomas merton and michael moorcock have in common', 'who was the first person to describe relational quantum mechanics and has worked in italy the united states and france', 'where is the silver dollar city theme park with the grand exposition  steel roller coaster located', 'finna get loose is a song by puff daddy and what american rapper who is also a record and film producer', 'what town is hore abbey located near', 'in what year was the actress who was starred in the telling with holly madison born']
# Processing started at: 2024-06-09 16:49:07.102569
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 92
#      90 wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
#      91 output_file_path = '/home/eternal/processed_wikipedia.txt/relevant_sentences1.txt'
# ---> 92 extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path)
#      93 print(f"Extracted relevant sentences saved to {output_file_path}.")
#
# Cell In[1], line 63, in extract_and_preprocess_sentences(questions, wiki_file_path, output_file_path, num_workers)
#      61 completed_processes = 0
#      62 while completed_processes < num_workers:
# ---> 63     result = output_queue.get()
#      64     if result[0] == "DONE":
#      65         worker_id = result[1]
#
# File /usr/lib/python3.10/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     101 if block and timeout is None:
#     102     with self._rlock:
# --> 103         res = self._recv_bytes()
#     104     self._sem.release()
#     105 else:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /usr/lib/python3.10/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File /usr/lib/python3.10/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     377 remaining = size
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#     381     if n == 0:
#
# KeyboardInterrupt:

# %%
# 데미지2

import ijson
import re
import os
import time
import multiprocessing
from rank_bm25 import BM25Okapi
from datetime import datetime
from transformers import BertTokenizer, BertModel
import torch
import numpy as np

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    return text

def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(preprocess_text(value))
    return questions

def get_bert_embeddings(sentences, model, tokenizer):
    inputs = tokenizer(sentences, return_tensors='pt', padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)

def calculate_similarity(embedding1, embedding2):
    return torch.cosine_similarity(embedding1, embedding2)

# %%
qa_file_path = '/home/eternal/qa_train.json'
questions = extract_questions(qa_file_path)
print(questions[:10])  # 추출된 질문 일부 출력
# Out:
# ['in what year the the venue that marcia white is president of open', 'what country is home to the sports club loaning bruno paulista to vasco da gama', 'southern air featured ray stevens minnie pearl and what other southern comedian', 'the treaty of prairie du chien may refer to any of several treaties made between the united states and representatives from the native american people who called themselves what', 'what profession do thomas merton and michael moorcock have in common', 'who was the first person to describe relational quantum mechanics and has worked in italy the united states and france', 'where is the silver dollar city theme park with the grand exposition  steel roller coaster located', 'finna get loose is a song by puff daddy and what american rapper who is also a record and film producer', 'what town is hore abbey located near', 'in what year was the actress who was starred in the telling with holly madison born']

# %%
def bm25_bert_worker(wiki_lines, questions, worker_id, output_queue, progress_array, model_name, tokenizer_name):
    try:
        print(f"Worker {worker_id} started.")
        tokenizer = BertTokenizer.from_pretrained(tokenizer_name)
        model = BertModel.from_pretrained(model_name)
        tokenized_corpus = [preprocess_text(line).split() for line in wiki_lines]
        bm25 = BM25Okapi(tokenized_corpus)
        relevant_sentences = []

        total_questions = len(questions)
        for idx, question in enumerate(questions):
            if idx % 100 == 0:
                print(f"Worker {worker_id}: Processing question {idx}/{total_questions}")
            
            tokenized_question = question.split()
            bm25_scores = bm25.get_scores(tokenized_question)
            top_n_indices = sorted(range(len(bm25_scores)), key=lambda i: bm25_scores[i], reverse=True)[:5]
            top_n_sentences = [wiki_lines[i] for i in top_n_indices]

            question_embedding = get_bert_embeddings([question], model, tokenizer)
            sentence_embeddings = get_bert_embeddings(top_n_sentences, model, tokenizer)
            similarities = [calculate_similarity(question_embedding, sentence_embedding.unsqueeze(0)) for sentence_embedding in sentence_embeddings]

            best_sentence_idx = similarities.index(max(similarities))
            relevant_sentences.append(top_n_sentences[best_sentence_idx])

            if (idx + 1) % 10 == 0:  # 10개의 질문마다 진행 상황을 업데이트
                progress_array[worker_id] = idx + 1

        output_queue.put((worker_id, relevant_sentences))
        output_queue.put(("DONE", worker_id))
    except Exception as e:
        output_queue.put((worker_id, f"ERROR: {e}"))
        print(f"Worker {worker_id} encountered an error: {e}")

def extract_and_preprocess_sentences_single_process(questions, wiki_file_path, output_file_path):
    start_time = datetime.now()
    print(f"Processing started at: {start_time}")

    model_name = 'bert-base-uncased'
    tokenizer_name = 'bert-base-uncased'

    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        wiki_lines = wiki_file.readlines()

    output_queue = multiprocessing.Queue()
    progress_array = multiprocessing.Array('i', 1)

    bm25_bert_worker(wiki_lines, questions, 0, output_queue, progress_array, model_name, tokenizer_name)

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        while not output_queue.empty():
            result = output_queue.get()
            if result[0] == "DONE":
                print(f"Worker completed.")
            elif result[0] == "ERROR":
                worker_id, error_message = result
                print(f"Worker encountered an error: {error_message}")
            else:
                worker_id, processed_lines = result
                output_file.writelines(processed_lines)
                print(f"Processed {len(processed_lines)} lines.")

    end_time = datetime.now()
    elapsed_time = (end_time - start_time).total_seconds()
    print(f"Processing completed at: {end_time}")
    print(f"Total processing time: {elapsed_time:.2f} seconds")

# %%
wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path = '/home/eternal/processed_wikipedia.txt/relevant_sentences.txt'
extract_and_preprocess_sentences_single_process(questions, wiki_file_path, output_file_path)
print(f"Extracted relevant sentences saved to {output_file_path}.")
# Out:
# Processing started at: 2024-06-09 19:10:30.271591
# Worker 0 started.

# %%
#동일하게 데미지

import ijson
import re
from difflib import SequenceMatcher
import nltk
from nltk.corpus import words
from spellchecker import SpellChecker
import sys
import time
from multiprocessing import Pool

# Ensure nltk word list is downloaded
nltk.download('words')

# %%
def extract_questions(file_path):
    questions = []
    with open(file_path, 'r', encoding='utf-8') as file:
        parser = ijson.parse(file)
        for prefix, event, value in parser:
            if prefix.endswith('.question') and event == 'string':
                questions.append(value)
    return questions

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\W+', ' ', text)
    return text

def correct_spelling(text):
    spell = SpellChecker()
    corrected_text = []
    for word in text.split():
        corrected_word = spell.correction(word)
        if corrected_word is None:
            corrected_word = word
        corrected_text.append(corrected_word)
    return ' '.join(corrected_text)

def is_relevant_sentence(question, sentence, threshold=0.6):
    question = correct_spelling(preprocess_text(question))
    sentence = correct_spelling(preprocess_text(sentence))
    similarity = SequenceMatcher(None, question, sentence).ratio()
    return similarity > threshold

def process_chunk(questions, chunk, threshold=0.6):
    relevant_sentences = set()
    for line in chunk:
        for question in questions:
            if is_relevant_sentence(question, line, threshold):
                relevant_sentences.add(line.strip())
                break
    return relevant_sentences

def extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path, chunk_size=1000, num_workers=12):
    relevant_sentences = set()
    total_lines = sum(1 for _ in open(wiki_file_path, 'r', encoding='utf-8'))

    start_time = time.time()
    with open(wiki_file_path, 'r', encoding='utf-8') as wiki_file:
        pool = Pool(num_workers)
        chunk = []
        for i, line in enumerate(wiki_file):
            chunk.append(line)
            if (i + 1) % chunk_size == 0:
                elapsed_time = time.time() - start_time
                lines_processed = i + 1
                remaining_lines = total_lines - lines_processed
                estimated_total_time = (elapsed_time / lines_processed) * total_lines
                estimated_remaining_time = estimated_total_time - elapsed_time
                print(f"Processing line {lines_processed}/{total_lines}")
                print(f"Elapsed time: {elapsed_time:.2f} seconds")
                print(f"Estimated remaining time: {estimated_remaining_time / 3600:.2f} hours")
                sys.stdout.flush()
                # Use starmap to pass multiple arguments to process_chunk
                results = pool.starmap(process_chunk, [(questions, chunk, 0.6)])
                for result in results:
                    relevant_sentences.update(result)
                chunk = []
        
        # Process remaining lines
        if chunk:
            results = pool.starmap(process_chunk, [(questions, chunk, 0.6)])
            for result in results:
                relevant_sentences.update(result)

    pool.close()
    pool.join()

    with open(output_file_path, 'w', encoding='utf-8') as output_file:
        for sentence in relevant_sentences:
            output_file.write(sentence + '\n')

    return relevant_sentences

# %%
# 파일 경로 설정
qa_file_path = '/home/eternal/qa_train.json'
wiki_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia.txt'
output_file_path = '/home/eternal/processed_wikipedia.txt/processed_wikipedia_filtered.txt'

# 질문 추출
print("Extracting questions...")
questions = extract_questions(qa_file_path)
print(f"Extracted {len(questions)} questions.")
print(questions[:10])  # 추출된 질문 일부 출력

# 관련 문장 추출 및 저장
print("Extracting relevant sentences...")
relevant_sentences = extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path)
print(f"Extracted {len(relevant_sentences)} relevant sentences.")
# Out:
# Extracting questions...
# Extracted 88066 questions.
# ['In what year the the venue that Marcia White is president of open?', 'What country is home to the sports club loaning Bruno Paulista to Vasco da Gama?', '"Southern Air" featured Ray Stevens, Minnie Pearl and what other Southern comedian?', 'The Treaty of Prairie du Chien may refer to any of several treaties made between the United States and representatives from the native american people who called themselves what?', 'What profession do Thomas Merton and Michael Moorcock have in common?', 'Who was the first person to describe Relational Quantum mechanics and has worked in Italy, the United States, and France?', 'Where is the Silver Dollar city theme park with the Grand exposition  steel roller coaster located?', 'Finna Get Loose is a song by Puff Daddy and what American rapper who is also a record and film producer?', 'What town is Hore Abbey located near?', 'In what year was the actress who was starred in "The Telling" with Holly Madison born?']
# Extracting relevant sentences...
# Processing line 1000/105502474
# Elapsed time: 2.48 seconds
# Estimated remaining time: 72.67 hours
# Process ForkPoolWorker-106:
# Process ForkPoolWorker-107:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-97:
# Process ForkPoolWorker-98:
# Process ForkPoolWorker-108:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 14
#      12 # 관련 문장 추출 및 저장
#      13 print("Extracting relevant sentences...")
# ---> 14 relevant_sentences = extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path)
#      15 print(f"Extracted {len(relevant_sentences)} relevant sentences.")
#
# Cell In[14], line 61, in extract_and_replace_relevant_sentences(questions, wiki_file_path, output_file_path, chunk_size, num_workers)
#      59 sys.stdout.flush()
#      60 # Use starmap to pass multiple arguments to process_chunk
# ---> 61 results = pool.starmap(process_chunk, [(questions, chunk, 0.6)])
#      62 for result in results:
#      63     relevant_sentences.update(result)
#
# File /usr/lib/python3.10/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /usr/lib/python3.10/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /usr/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-105:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-101:
# Process ForkPoolWorker-103:
# Process ForkPoolWorker-99:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/tmp/ipykernel_25677/85990744.py", line 35, in process_chunk
#     if is_relevant_sentence(question, line, threshold):
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/tmp/ipykernel_25677/85990744.py", line 26, in is_relevant_sentence
#     question = correct_spelling(preprocess_text(question))
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/tmp/ipykernel_25677/85990744.py", line 19, in correct_spelling
#     corrected_word = spell.correction(word)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/eternal/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py", line 158, in correction
#     candidates = self.candidates(word)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/eternal/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py", line 185, in candidates
#     tmp = self.known(list(self.__edit_distance_alt(res)))
# KeyboardInterrupt
#   File "/home/eternal/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py", line 252, in __edit_distance_alt
#     return [e2 for e1 in tmp for e2 in self.known(self.edit_distance_1(e1))]
#   File "/home/eternal/.local/lib/python3.10/site-packages/spellchecker/spellchecker.py", line 252, in <listcomp>
#     return [e2 for e1 in tmp for e2 in self.known(self.edit_distance_1(e1))]
# KeyboardInterrupt
